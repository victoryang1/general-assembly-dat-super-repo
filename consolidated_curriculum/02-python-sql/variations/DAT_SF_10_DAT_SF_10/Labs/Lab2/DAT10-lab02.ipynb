# %% [markdown]
# # GA Data Science 10 (DAT5) - Lab2
#
# ### Importing Data - JSON, CSVs, APIs
#
# Craig Sakuma

# %% [markdown]
# ### Last time we covered introductions to:
# - #### Python
# - #### iPython Notebooks
# - #### numpy
# - #### Pandas
#
# #### Questions?

# %% [markdown]
# ### Agenda
#
# 1. JSON
# 2. API

# %% [markdown]
# # 1. JSON

# %% [markdown]
# - What's Json? (and why do we care?)

# %%
# load the homework data into a pandas dataset

import pandas as pd

data = pd.read_csv("titanic-train.csv")

# %%
# assign the first 5 rows to a variable called first

first = data.head(5)

# %%
first
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# use the DataFrame method to_json to transform <first> into a json object
first.to_json()
# Out:
# '{"PassengerId":{"0":1,"1":2,"2":3,"3":4,"4":5},"Survived":{"0":0,"1":1,"2":1,"3":1,"4":0},"Pclass":{"0":3,"1":1,"2":3,"3":1,"4":3},"Name":{"0":"Braund, Mr. Owen Harris","1":"Cumings, Mrs. John Bradley (Florence Briggs Thayer)","2":"Heikkinen, Miss. Laina","3":"Futrelle, Mrs. Jacques Heath (Lily May Peel)","4":"Allen, Mr. William Henry"},"Sex":{"0":"male","1":"female","2":"female","3":"female","4":"male"},"Age":{"0":22.0,"1":38.0,"2":26.0,"3":35.0,"4":35.0},"SibSp":{"0":1,"1":1,"2":0,"3":1,"4":0},"Parch":{"0":0,"1":0,"2":0,"3":0,"4":0},"Ticket":{"0":"A\\/5 21171","1":"PC 17599","2":"STON\\/O2. 3101282","3":"113803","4":"373450"},"Fare":{"0":7.25,"1":71.2833,"2":7.925,"3":53.1,"4":8.05},"Cabin":{"0":null,"1":"C85","2":null,"3":"C123","4":null},"Embarked":{"0":"S","1":"C","2":"S","3":"S","4":"S"}}'

# %%
# explore the different options in the to_json method
first.to_json(orient = 'records')
# Out:
# '[{"PassengerId":1,"Survived":0,"Pclass":3,"Name":"Braund, Mr. Owen Harris","Sex":"male","Age":22.0,"SibSp":1,"Parch":0,"Ticket":"A\\/5 21171","Fare":7.25,"Cabin":null,"Embarked":"S"},{"PassengerId":2,"Survived":1,"Pclass":1,"Name":"Cumings, Mrs. John Bradley (Florence Briggs Thayer)","Sex":"female","Age":38.0,"SibSp":1,"Parch":0,"Ticket":"PC 17599","Fare":71.2833,"Cabin":"C85","Embarked":"C"},{"PassengerId":3,"Survived":1,"Pclass":3,"Name":"Heikkinen, Miss. Laina","Sex":"female","Age":26.0,"SibSp":0,"Parch":0,"Ticket":"STON\\/O2. 3101282","Fare":7.925,"Cabin":null,"Embarked":"S"},{"PassengerId":4,"Survived":1,"Pclass":1,"Name":"Futrelle, Mrs. Jacques Heath (Lily May Peel)","Sex":"female","Age":35.0,"SibSp":1,"Parch":0,"Ticket":"113803","Fare":53.1,"Cabin":"C123","Embarked":"S"},{"PassengerId":5,"Survived":0,"Pclass":3,"Name":"Allen, Mr. William Henry","Sex":"male","Age":35.0,"SibSp":0,"Parch":0,"Ticket":"373450","Fare":8.05,"Cabin":null,"Embarked":"S"}]'

# %% [markdown]
# # 2. APIs

# %% [markdown]
# - What's an API? (and why do we care?)

# %% [markdown]
# ## 2.a A simple web request

# %%
import urllib

def get_historical_prices(symbol, start_date, end_date):
    """
    Get historical prices for the given ticker symbol.
    Date format is 'YYYYMMDD'
    
    Returns a json list.
    """
    url = 'http://ichart.yahoo.com/table.csv?s=%s&' % symbol + \
          'd=%s&' % str(int(end_date[4:6]) - 1) + \
          'e=%s&' % str(int(end_date[6:8])) + \
          'f=%s&' % str(int(end_date[0:4])) + \
          'g=d&' + \
          'a=%s&' % str(int(start_date[4:6]) - 1) + \
          'b=%s&' % str(int(start_date[6:8])) + \
          'c=%s&' % str(int(start_date[0:4])) + \
          'ignore=.csv'
    days = urllib.urlopen(url).readlines()
#     return days
    data = [day[:-2].split(',') for day in days]
    return data

# %%
get_historical_prices('GOOGL', '20140101', '20140106')
# Out:
# [['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Clos'],
#  ['2014-01-06',
#   '1113.01',
#   '1118.86',
#   '1106.44',
#   '1117.32',
#   '3535000',
#   '559.2'],
#  ['2014-01-03',
#   '1115.00',
#   '1116.93',
#   '1104.93',
#   '1105.00',
#   '3330000',
#   '553.0'],
#  ['2014-01-02',
#   '1115.46',
#   '1117.75',
#   '1108.26',
#   '1113.12',
#   '3639100',
#   '557.1']]

# %%
# obtain the prices of Yahoo for the past month and insert them in a Pandas Dataframe

prices =get_historical_prices('YHOO', '20140217', '20140317')

df = pd.DataFrame(prices[1:], columns= prices[0], dtype=float).set_index('Date')
df.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Clos
# Date
# 2014-03-17  39.00  39.36  38.61  39.11  29698300      39.1
# 2014-03-14  36.69  38.19  36.45  37.60  30862300      37.6
# 2014-03-13  38.05  38.42  36.81  37.23  21179700      37.2
# 2014-03-12  37.21  37.61  36.48  37.50  14794700      37.5
# 2014-03-11  38.25  38.30  37.43  37.56  12592300      37.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 2014-03-17 to 2014-02-18
# Data columns (total 6 columns):
# Open        20 non-null float64
# High        20 non-null float64
# Low         20 non-null float64
# Close       20 non-null float64
# Volume      20 non-null float64
# Adj Clos    20 non-null float64
# dtypes: float64(6)

# %% [markdown]
# ### Exercise 1
# ##### Create a pandas dataframe with all the stock price data for Alibaba (BABA)
# ##### What was the highest trading price of the Alibaba stock?
# ##### What was the lowest trading price of the Alibaba stock?
#
# #### Hint: Look in pandas documentation or stackoverflow
#
# ### Bonus Question
# ##### What were the Yahoo highs and lows for the same days as the Alibaba highs and lows?

# %%
df.index[df.High==df.High.max()]
# Out:
#              Open   High    Low  Close    Volume  Adj Clos
# Date
# 2014-03-05  39.83  40.15  39.19   39.5  12536800      39.5

# %% [markdown]
# ## 2.b Unstructured data

# %% [markdown]
# #### HTTP requests can be handled easily using Python's `requests` library.
#
# First we will load our credentials which we keep in a [YAML](http://www.yaml.org/) file for safe keeping.

# %%
import yaml
credentials = yaml.load(open('/users/Craig_Sakuma/api_cred.yml'))

# %% [markdown]
# Then we pass those credentials in to a GET request using the requests library. In this case, I am querying my own user data from Github:

# %%
import requests
r = requests.get('https://api.github.com/user', 
                 auth=(credentials['USER'], credentials['PASS']))

# %% [markdown]
# Requests gives us an object from which we can read its content.

# %%
r.content
# Out:
# '{"login":"craigsakuma","id":4754768,"avatar_url":"https://avatars.githubusercontent.com/u/4754768?v=2","gravatar_id":"","url":"https://api.github.com/users/craigsakuma","html_url":"https://github.com/craigsakuma","followers_url":"https://api.github.com/users/craigsakuma/followers","following_url":"https://api.github.com/users/craigsakuma/following{/other_user}","gists_url":"https://api.github.com/users/craigsakuma/gists{/gist_id}","starred_url":"https://api.github.com/users/craigsakuma/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/craigsakuma/subscriptions","organizations_url":"https://api.github.com/users/craigsakuma/orgs","repos_url":"https://api.github.com/users/craigsakuma/repos","events_url":"https://api.github.com/users/craigsakuma/events{/privacy}","received_events_url":"https://api.github.com/users/craigsakuma/received_events","type":"User","site_admin":false,"public_repos":3,"public_gists":0,"followers":1,"following":3,"created_at":"2013-06-21T01:32:11Z","updated_at":"2014-10-07T02:00:21Z","private_gists":0,"total_private_repos":0,"owned_private_repos":0,"disk_usage":88748,"collaborators":0,"plan":{"name":"free","space":307200,"collaborators":0,"private_repos":0}}'

# %% [markdown]
# #### One of the reasons we like JSON is that it is easy to transform into a Python `dict` object using the `json` library:

# %%
import json
user = json.loads(r.content)
user
# Out:
# {u'avatar_url': u'https://avatars.githubusercontent.com/u/4754768?v=2',
#  u'collaborators': 0,
#  u'created_at': u'2013-06-21T01:32:11Z',
#  u'disk_usage': 88748,
#  u'events_url': u'https://api.github.com/users/craigsakuma/events{/privacy}',
#  u'followers': 1,
#  u'followers_url': u'https://api.github.com/users/craigsakuma/followers',
#  u'following': 3,
#  u'following_url': u'https://api.github.com/users/craigsakuma/following{/other_user}',
#  u'gists_url': u'https://api.github.com/users/craigsakuma/gists{/gist_id}',
#  u'gravatar_id': u'',
#  u'html_url': u'https://github.com/craigsakuma',
#  u'id': 4754768,
#  u'login': u'craigsakuma',
#  u'organizations_url': u'https://api.github.com/users/craigsakuma/orgs',
#  u'owned_private_repos': 0,
#  u'plan': {u'collaborators': 0,
#   u'name': u'free',
#   u'private_repos': 0,
#   u'space': 307200},
#  u'private_gists': 0,
#  u'public_gists': 0,
#  u'public_repos': 3,
#  u'received_events_url': u'https://api.github.com/users/craigsakuma/received_events',
#  u'repos_url': u'https://api.github.com/users/craigsakuma/repos',
#  u'site_admin': False,
#  u'starred_url': u'https://api.github.com/users/craigsakuma/starred{/owner}{/repo}',
#  u'subscriptions_url': u'https://api.github.com/users/craigsakuma/subscriptions',
#  u'total_private_repos': 0,
#  u'type': u'User',
#  u'updated_at': u'2014-10-07T02:00:21Z',
#  u'url': u'https://api.github.com/users/craigsakuma'}

# %%
print user.keys()
# Out:
# [u'disk_usage', u'private_gists', u'site_admin', u'subscriptions_url', u'gravatar_id', u'id', u'followers_url', u'following_url', u'collaborators', u'total_private_repos', u'followers', u'type', u'public_repos', u'gists_url', u'owned_private_repos', u'events_url', u'html_url', u'updated_at', u'plan', u'received_events_url', u'starred_url', u'public_gists', u'organizations_url', u'url', u'created_at', u'avatar_url', u'repos_url', u'following', u'login']

# %% [markdown]
# We can access values in this dict directly (such as my hireable status) and even render the url of my avatar:

# %%
from IPython.display import HTML
print "Hireable: {}".format(user.get('hireable'))
HTML('<img src={} />'.format(user.get('avatar_url')))
# Out:
# Hireable: None
# <img src=https://avatars.githubusercontent.com/u/4754768?v=2 />

# %% [markdown]
# # Twitter API

# %% [markdown]
# Twitter has no less than 10 python libraries. We'll be using Python Twitter Tools because it's what's used in Mining the Social Web.

# %% [markdown]
# #### Some services (like Twitter) have released Python libraries of their own to make using their API even easier.

# %%
import twitter

auth = twitter.oauth.OAuth(credentials['OAUTH_TOKEN'], 
                           credentials['OAUTH_TOKEN_SECRET'],
                           credentials['CONSUMER_KEY'],
                           credentials['CONSUMER_SECRET'])

twitter_api = twitter.Twitter(auth=auth)

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x107cb77d0>

# %% [markdown]
# #### Using a library like this, we don't even need to specify the URL (that's handled internally).

# %% [markdown]
# Using a library like this, it's easy to do something like search for tweets mentioning `#bigdata`
#
# The results are transformed into a Python object (which in this case is a thin wrapper around a `dict`)

# %%
bigdata = twitter_api.search.tweets(q='#bigdata', count=5)
type(bigdata)
# Out:
# twitter.api.TwitterDictResponse

# %%
for status in bigdata['statuses']:
    print status.get('text')
# Out:
# #StopDataRetention
#
# #qt #auspol #brandis #snowden #asio #heyasio #privacy #surveillance #metadata #bigdata http://t.co/DJc1ppDyO3
# RT @TungstenBigData: Business Intelligence/Data Warehouse Architect (Full Time) http://t.co/Ni1UVA6yxy #BI #BigData
# RT @TungstenBigData: Business Intelligence/Data Warehouse Architect (Full Time) http://t.co/Ni1UVA6yxy #BI #BigData
# RT @datanami: Off The Wire: @Zoomdata Receives $17M in Funding http://t.co/0qrMAnoytJ #BigData
# RT @Shyam17: The next generation of data integration technology for the changing cloud market http://t.co/DWdhKHTAUo http://t.co/0XeuZ6x5xG…

# %% [markdown]
# # Twitter lab
# [http://tinyurl.com/GAtwitterlab](http://nbviewer.ipython.org/github/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/ipynb/Chapter%201%20-%20Mining%20Twitter.ipynb) up through Exercise 5

# %% [markdown]
# Useful links:
#
# [Mining the Social Web](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition)

# %%
# !pip install twitter
# Out:
# Requirement already satisfied (use --upgrade to upgrade): twitter in /Users/Craig_Sakuma/anaconda/lib/python2.7/site-packages
# Cleaning up...

# %%
import twitter

# %% [markdown]
# ### Create your own Twitter credentials:
#
# #### Step 1:
# Go to https://dev.twitter.com/apps and sign in.
#
# #### Step 2:
# Register an application (doesn't have to be real, just a placeholder)
#
# Website: http://example.com
#
# Callback URL: http://example.com/auth/twitter/callback/
#
# #### Step 3:
# Add api key and api secret to your yaml file
#
# #### Step 4:
# Click on generate token and add information into your yaml file

# %% [markdown]
# ### Create your own yaml file called api_cred.yml
# Use the credential_example.yml file as a template

# %%
credentials = yaml.load(open('/users/Craig_Sakuma/api_cred.yml'))
auth = twitter.oauth.OAuth(credentials['OAUTH_TOKEN'], 
                           credentials['OAUTH_TOKEN_SECRET'],
                           credentials['CONSUMER_KEY'],
                           credentials['CONSUMER_SECRET'])

# %%
twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print twitter_api
# Out:
# <twitter.api.Twitter object at 0x1072f4750>

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2014-10-07T04:25:26Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23LesserBondMovies', u'query': u'%23LesserBondMovies', u'name': u'#LesserBondMovies', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23HannaJKT48KapanKeBanjarmasin', u'query': u'%23HannaJKT48KapanKeBanjarmasin', u'name': u'#HannaJKT48KapanKeBanjarmasin', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23Fikri_kapten', u'query': u'%23Fikri_kapten', u'name': u'#Fikri_kapten', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23ZaynDeservesPrivacy', u'query': u'%23ZaynDeservesPrivacy', u'name': u'#ZaynDeservesPrivacy', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23NoMeVendriaNadaMal', u'query': u'%23NoMeVendriaNadaMal', u'name': u'#NoMeVendriaNadaMal', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22AneFirman%3C3+Ayudya%22', u'query': u'%22AneFirman%3C3+Ayudya%22', u'name': u'AneFirman<3 Ayudya', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Cek+Timline+TanyaaNesian%22', u'query': u'%22Cek+Timline+TanyaaNesian%22', u'name': u'Cek Timline TanyaaNesian', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22BebyJKT48+Digilir+Rizky+Febri+H%22', u'query': u'%22BebyJKT48+Digilir+Rizky+Febri+H%22', u'name': u'BebyJKT48 Digilir Rizky Febri H', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Gary+Harris%22', u'query': u'%22Gary+Harris%22', u'name': u'Gary Harris', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Dale+Scott%22', u'query': u'%22Dale+Scott%22', u'name': u'Dale Scott', u'promoted_content': None}], u'as_of': u'2014-10-07T04:31:11Z', u'locations': [{u'woeid': 1, u'name': u'Worldwide'}]}]
#
# [{u'created_at': u'2014-10-07T04:25:26Z', u'trends': [{u'url': u'http://twitter.com/search?q=%23LesserBondMovies', u'query': u'%23LesserBondMovies', u'name': u'#LesserBondMovies', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Carol+Burnett%22', u'query': u'%22Carol+Burnett%22', u'name': u'Carol Burnett', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%235SOSGOODGIRLS', u'query': u'%235SOSGOODGIRLS', u'name': u'#5SOSGOODGIRLS', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23ZaynDeservesPrivacy', u'query': u'%23ZaynDeservesPrivacy', u'name': u'#ZaynDeservesPrivacy', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Gary+Harris%22', u'query': u'%22Gary+Harris%22', u'name': u'Gary Harris', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23Tensions', u'query': u'%23Tensions', u'name': u'#Tensions', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Dale+Scott%22', u'query': u'%22Dale+Scott%22', u'name': u'Dale Scott', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Casino+Royale+with+Cheese%22', u'query': u'%22Casino+Royale+with+Cheese%22', u'name': u'Casino Royale with Cheese', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Kershaw+and+Greinke%22', u'query': u'%22Kershaw+and+Greinke%22', u'name': u'Kershaw and Greinke', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%22Ed+Davis%22', u'query': u'%22Ed+Davis%22', u'name': u'Ed Davis', u'promoted_content': None}], u'as_of': u'2014-10-07T04:31:11Z', u'locations': [{u'woeid': 23424977, u'name': u'United States'}]}]

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2014-10-07T04:25:26Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23LesserBondMovies",
#     "query": "%23LesserBondMovies",
#     "name": "#LesserBondMovies",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HannaJKT48KapanKeBanjarmasin",
#     "query": "%23HannaJKT48KapanKeBanjarmasin",
#     "name": "#HannaJKT48KapanKeBanjarmasin",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Fikri_kapten",
#     "query": "%23Fikri_kapten",
#     "name": "#Fikri_kapten",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ZaynDeservesPrivacy",
#     "query": "%23ZaynDeservesPrivacy",
#     "name": "#ZaynDeservesPrivacy",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NoMeVendriaNadaMal",
#     "query": "%23NoMeVendriaNadaMal",
#     "name": "#NoMeVendriaNadaMal",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22AneFirman%3C3+Ayudya%22",
#     "query": "%22AneFirman%3C3+Ayudya%22",
#     "name": "AneFirman<3 Ayudya",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Cek+Timline+TanyaaNesian%22",
#     "query": "%22Cek+Timline+TanyaaNesian%22",
#     "name": "Cek Timline TanyaaNesian",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22BebyJKT48+Digilir+Rizky+Febri+H%22",
#     "query": "%22BebyJKT48+Digilir+Rizky+Febri+H%22",
#     "name": "BebyJKT48 Digilir Rizky Febri H",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Gary+Harris%22",
#     "query": "%22Gary+Harris%22",
#     "name": "Gary Harris",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Dale+Scott%22",
#     "query": "%22Dale+Scott%22",
#     "name": "Dale Scott",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-10-07T04:31:11Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2014-10-07T04:25:26Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23LesserBondMovies",
#     "query": "%23LesserBondMovies",
#     "name": "#LesserBondMovies",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Carol+Burnett%22",
#     "query": "%22Carol+Burnett%22",
#     "name": "Carol Burnett",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%235SOSGOODGIRLS",
#     "query": "%235SOSGOODGIRLS",
#     "name": "#5SOSGOODGIRLS",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ZaynDeservesPrivacy",
#     "query": "%23ZaynDeservesPrivacy",
#     "name": "#ZaynDeservesPrivacy",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Gary+Harris%22",
#     "query": "%22Gary+Harris%22",
#     "name": "Gary Harris",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Tensions",
#     "query": "%23Tensions",
#     "name": "#Tensions",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Dale+Scott%22",
#     "query": "%22Dale+Scott%22",
#     "name": "Dale Scott",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Casino+Royale+with+Cheese%22",
#     "query": "%22Casino+Royale+with+Cheese%22",
#     "name": "Casino Royale with Cheese",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Kershaw+and+Greinke%22",
#     "query": "%22Kershaw+and+Greinke%22",
#     "name": "Kershaw and Greinke",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Ed+Davis%22",
#     "query": "%22Ed+Davis%22",
#     "name": "Ed Davis",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2014-10-07T04:31:11Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'#ZaynDeservesPrivacy', u'Gary Harris', u'#LesserBondMovies', u'Dale Scott'])

# %%
q = '#DataScience' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

# print json.dumps(search_results, indent=1)
print json.dumps(statuses, indent=1)
# Out:
# [
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @Terry_Timko: Now #DataDriven\n... how @AIG Moved 2 Evidence-Based Decision Making\nhttp://t.co/f6FWot3Lxw #datascience #bigdata",
#   "in_reply_to_status_id": null,
#   "id": 519344075099500544,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 162039396,
#      "indices": [
#       3,
#       15
#      ],
#      "id_str": "162039396",
#      "screen_name": "Terry_Timko",
#      "name": "Terry Timko"
#     },
#     {
#      "id": 15851753,
#      "indices": [
#       41,
#       45
#      ],
#      "id_str": "15851753",
#      "screen_name": "AiG",
#      "name": "Answers in Genesis"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       21,
#       32
#      ],
#      "text": "DataDriven"
#     },
#     {
#      "indices": [
#       108,
#       120
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       121,
#       129
#      ],
#      "text": "bigdata"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/f6FWot3Lxw",
#      "indices": [
#       85,
#       107
#      ],
#      "expanded_url": "http://blogs.hbr.org/2014/10/how-aig-moved-toward-evidence-based-decision-making/",
#      "display_url": "blogs.hbr.org/2014/10/how-ai\u2026"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519344075099500544",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1379052655,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#    "verified": false,
#    "profile_text_color": "666666",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/489999658010152960/eH7CiGIr_normal.jpeg",
#    "profile_sidebar_fill_color": "252429",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/NLXYU7yefu",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://in.linkedin.com/in/ramakrishnanm/",
#        "display_url": "in.linkedin.com/in/ramakrishna\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 366,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "1379052655",
#    "profile_background_color": "1A1B1F",
#    "listed_count": 7,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 1377,
#    "description": "Full-time father. Part-time Coach. Advisor to Nonprofit. \n#decisionengineering & #bigdata #Analytics @Absolutdata. #SaaS and #customersuccess maven.",
#    "friends_count": 581,
#    "location": "San Francisco, New Delhi",
#    "profile_link_color": "11164D",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/489999658010152960/eH7CiGIr_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#    "screen_name": "ramakrishnan_m_",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 932,
#    "name": "Ramakrishnan M",
#    "notifications": false,
#    "url": "http://t.co/NLXYU7yefu",
#    "created_at": "Thu Apr 25 09:14:20 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Tue Oct 07 04:30:51 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @thinkBigA: Don't miss @thinkBigA's Sr. #DataScientist Field Cady on \"#Python for #DataScience\" tomorrow at @pawcon Boston 2014 http://t\u2026",
#   "in_reply_to_status_id": null,
#   "id": 519343401230405635,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 171783994,
#      "indices": [
#       3,
#       13
#      ],
#      "id_str": "171783994",
#      "screen_name": "thinkBigA",
#      "name": "Think Big"
#     },
#     {
#      "id": 171783994,
#      "indices": [
#       26,
#       36
#      ],
#      "id_str": "171783994",
#      "screen_name": "thinkBigA",
#      "name": "Think Big"
#     },
#     {
#      "id": 50010864,
#      "indices": [
#       111,
#       118
#      ],
#      "id_str": "50010864",
#      "screen_name": "pawcon",
#      "name": "Predictive Analytics"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       43,
#       57
#      ],
#      "text": "DataScientist"
#     },
#     {
#      "indices": [
#       73,
#       80
#      ],
#      "text": "Python"
#     },
#     {
#      "indices": [
#       85,
#       97
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/NNGc0dWqiT",
#      "indices": [
#       139,
#       140
#      ],
#      "expanded_url": "http://ow.ly/ClwSq",
#      "display_url": "ow.ly/ClwSq"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 2,
#   "id_str": "519343401230405635",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Don't miss @thinkBigA's Sr. #DataScientist Field Cady on \"#Python for #DataScience\" tomorrow at @pawcon Boston 2014 http://t.co/NNGc0dWqiT",
#    "in_reply_to_status_id": null,
#    "id": 519219691899072513,
#    "favorite_count": 3,
#    "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 171783994,
#       "indices": [
#        11,
#        21
#       ],
#       "id_str": "171783994",
#       "screen_name": "thinkBigA",
#       "name": "Think Big"
#      },
#      {
#       "id": 50010864,
#       "indices": [
#        96,
#        103
#       ],
#       "id_str": "50010864",
#       "screen_name": "pawcon",
#       "name": "Predictive Analytics"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        28,
#        42
#       ],
#       "text": "DataScientist"
#      },
#      {
#       "indices": [
#        58,
#        65
#       ],
#       "text": "Python"
#      },
#      {
#       "indices": [
#        70,
#        82
#       ],
#       "text": "DataScience"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/NNGc0dWqiT",
#       "indices": [
#        116,
#        138
#       ],
#       "expanded_url": "http://ow.ly/ClwSq",
#       "display_url": "ow.ly/ClwSq"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 2,
#    "id_str": "519219691899072513",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 171783994,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/507141512165998593/v2Fvmkxs_normal.png",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/3yCvqLY95y",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://thinkbig.teradata.com",
#         "display_url": "thinkbig.teradata.com"
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "followers_count": 895,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "171783994",
#     "profile_background_color": "C0DEED",
#     "listed_count": 69,
#     "is_translation_enabled": false,
#     "utc_offset": null,
#     "statuses_count": 521,
#     "description": "Think Big, a Teradata company, is the leading professional services firm focused exclusively helping company unlock new insights and value from Big Data.",
#     "friends_count": 78,
#     "location": "Mountain View, CA",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/507141512165998593/v2Fvmkxs_normal.png",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "thinkBigA",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 2,
#     "name": "Think Big",
#     "notifications": false,
#     "url": "http://t.co/3yCvqLY95y",
#     "created_at": "Wed Jul 28 04:29:40 +0000 2010",
#     "contributors_enabled": false,
#     "time_zone": null,
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Mon Oct 06 20:16:35 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 93789912,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/3078301710/e2863154af4404f962771f6a35a57f88_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/Pp0piefBg5",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.thinkbiganalytics.com/",
#        "display_url": "thinkbiganalytics.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 107,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "93789912",
#    "profile_background_color": "C0DEED",
#    "listed_count": 7,
#    "is_translation_enabled": false,
#    "utc_offset": -14400,
#    "statuses_count": 437,
#    "description": "Big Data is my work, climbing is my passion.",
#    "friends_count": 155,
#    "location": "Winchester, MA",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/3078301710/e2863154af4404f962771f6a35a57f88_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "Douglas_MA",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 32,
#    "name": "Douglas Moore",
#    "notifications": false,
#    "url": "http://t.co/Pp0piefBg5",
#    "created_at": "Tue Dec 01 04:35:15 +0000 2009",
#    "contributors_enabled": false,
#    "time_zone": "Eastern Time (US & Canada)",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Tue Oct 07 04:28:10 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @Terry_Timko @eBay optimizes  listing 4 sellers thru #DataScience\nhttp://t.co/n1xWYt39xM http://t.co/70EDBK05ng #retail #ecommerce",
#   "in_reply_to_status_id": null,
#   "id": 519342993916964864,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 162039396,
#      "indices": [
#       3,
#       15
#      ],
#      "id_str": "162039396",
#      "screen_name": "Terry_Timko",
#      "name": "Terry Timko"
#     },
#     {
#      "id": 19709040,
#      "indices": [
#       16,
#       21
#      ],
#      "id_str": "19709040",
#      "screen_name": "eBay",
#      "name": "eBay"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       56,
#       68
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       115,
#       122
#      ],
#      "text": "retail"
#     },
#     {
#      "indices": [
#       123,
#       133
#      ],
#      "text": "ecommerce"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/n1xWYt39xM",
#      "indices": [
#       69,
#       91
#      ],
#      "expanded_url": "http://www.xconomy.com/seattle/2014/10/03/inside-ebay-decide-com-team-leads-seller-insights-startup-outreach/",
#      "display_url": "xconomy.com/seattle/2014/1\u2026"
#     }
#    ],
#    "media": [
#     {
#      "source_status_id_str": "519118431904595968",
#      "expanded_url": "http://twitter.com/Terry_Timko/status/519118431904595968/photo/1",
#      "display_url": "pic.twitter.com/70EDBK05ng",
#      "url": "http://t.co/70EDBK05ng",
#      "media_url_https": "https://pbs.twimg.com/media/BzRHdl-IIAAwEGS.png",
#      "source_status_id": 519118431904595968,
#      "id_str": "519118430788919296",
#      "sizes": {
#       "large": {
#        "h": 662,
#        "resize": "fit",
#        "w": 505
#       },
#       "small": {
#        "h": 445,
#        "resize": "fit",
#        "w": 340
#       },
#       "medium": {
#        "h": 662,
#        "resize": "fit",
#        "w": 505
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       92,
#       114
#      ],
#      "type": "photo",
#      "id": 519118430788919296,
#      "media_url": "http://pbs.twimg.com/media/BzRHdl-IIAAwEGS.png"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519342993916964864",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1379052655,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#    "verified": false,
#    "profile_text_color": "666666",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/489999658010152960/eH7CiGIr_normal.jpeg",
#    "profile_sidebar_fill_color": "252429",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/NLXYU7yefu",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://in.linkedin.com/in/ramakrishnanm/",
#        "display_url": "in.linkedin.com/in/ramakrishna\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 366,
#    "profile_sidebar_border_color": "FFFFFF",
#    "id_str": "1379052655",
#    "profile_background_color": "1A1B1F",
#    "listed_count": 7,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 1377,
#    "description": "Full-time father. Part-time Coach. Advisor to Nonprofit. \n#decisionengineering & #bigdata #Analytics @Absolutdata. #SaaS and #customersuccess maven.",
#    "friends_count": 581,
#    "location": "San Francisco, New Delhi",
#    "profile_link_color": "11164D",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/489999658010152960/eH7CiGIr_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#    "screen_name": "ramakrishnan_m_",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 932,
#    "name": "Ramakrishnan M",
#    "notifications": false,
#    "url": "http://t.co/NLXYU7yefu",
#    "created_at": "Thu Apr 25 09:14:20 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Tue Oct 07 04:26:33 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @KirkDBorne: Awesome visual summary of 270+ #DataViz tools &amp; resources\nhttp://t.co/IKe9d1D9u0 by @visualisingdata #DataScience http://t.\u2026",
#   "in_reply_to_status_id": null,
#   "id": 519342243748925440,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 534563976,
#      "indices": [
#       3,
#       14
#      ],
#      "id_str": "534563976",
#      "screen_name": "KirkDBorne",
#      "name": "Kirk Borne"
#     },
#     {
#      "id": 137712607,
#      "indices": [
#       104,
#       120
#      ],
#      "id_str": "137712607",
#      "screen_name": "visualisingdata",
#      "name": "Andy Kirk"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       47,
#       55
#      ],
#      "text": "DataViz"
#     },
#     {
#      "indices": [
#       121,
#       133
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/IKe9d1D9u0",
#      "indices": [
#       78,
#       100
#      ],
#      "expanded_url": "http://bit.ly/1wJr7yx",
#      "display_url": "bit.ly/1wJr7yx"
#     }
#    ],
#    "media": [
#     {
#      "source_status_id_str": "519324978266009600",
#      "expanded_url": "http://twitter.com/KirkDBorne/status/519324978266009600/photo/1",
#      "display_url": "pic.twitter.com/SawP4ZTqjG",
#      "url": "http://t.co/SawP4ZTqjG",
#      "media_url_https": "https://pbs.twimg.com/media/BzUDUM9IMAANpjn.jpg",
#      "source_status_id": 519324978266009600,
#      "id_str": "519324977641041920",
#      "sizes": {
#       "small": {
#        "h": 407,
#        "resize": "fit",
#        "w": 340
#       },
#       "large": {
#        "h": 1024,
#        "resize": "fit",
#        "w": 854
#       },
#       "medium": {
#        "h": 719,
#        "resize": "fit",
#        "w": 600
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       143,
#       144
#      ],
#      "type": "photo",
#      "id": 519324977641041920,
#      "media_url": "http://pbs.twimg.com/media/BzUDUM9IMAANpjn.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 6,
#   "id_str": "519342243748925440",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Awesome visual summary of 270+ #DataViz tools &amp; resources\nhttp://t.co/IKe9d1D9u0 by @visualisingdata #DataScience http://t.co/SawP4ZTqjG",
#    "in_reply_to_status_id": null,
#    "id": 519324978266009600,
#    "favorite_count": 9,
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 137712607,
#       "indices": [
#        88,
#        104
#       ],
#       "id_str": "137712607",
#       "screen_name": "visualisingdata",
#       "name": "Andy Kirk"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        31,
#        39
#       ],
#       "text": "DataViz"
#      },
#      {
#       "indices": [
#        105,
#        117
#       ],
#       "text": "DataScience"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/IKe9d1D9u0",
#       "indices": [
#        62,
#        84
#       ],
#       "expanded_url": "http://bit.ly/1wJr7yx",
#       "display_url": "bit.ly/1wJr7yx"
#      }
#     ],
#     "media": [
#      {
#       "expanded_url": "http://twitter.com/KirkDBorne/status/519324978266009600/photo/1",
#       "display_url": "pic.twitter.com/SawP4ZTqjG",
#       "url": "http://t.co/SawP4ZTqjG",
#       "media_url_https": "https://pbs.twimg.com/media/BzUDUM9IMAANpjn.jpg",
#       "id_str": "519324977641041920",
#       "sizes": {
#        "small": {
#         "h": 407,
#         "resize": "fit",
#         "w": 340
#        },
#        "large": {
#         "h": 1024,
#         "resize": "fit",
#         "w": 854
#        },
#        "medium": {
#         "h": 719,
#         "resize": "fit",
#         "w": 600
#        },
#        "thumb": {
#         "h": 150,
#         "resize": "crop",
#         "w": 150
#        }
#       },
#       "indices": [
#        118,
#        140
#       ],
#       "type": "photo",
#       "id": 519324977641041920,
#       "media_url": "http://pbs.twimg.com/media/BzUDUM9IMAANpjn.jpg"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 6,
#    "id_str": "519324978266009600",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 534563976,
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/452157174769524737/cknjYfAC_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/tWlmevaWIF",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://www.linkedin.com/in/kirkdborne",
#         "display_url": "linkedin.com/in/kirkdborne"
#        }
#       ]
#      },
#      "description": {
#       "urls": [
#        {
#         "url": "http://t.co/qYn8bft1fP",
#         "indices": [
#          130,
#          152
#         ],
#         "expanded_url": "http://kirkborne.net/",
#         "display_url": "kirkborne.net"
#        }
#       ]
#      }
#     },
#     "followers_count": 16372,
#     "profile_sidebar_border_color": "FFFFFF",
#     "id_str": "534563976",
#     "profile_background_color": "C0DEED",
#     "listed_count": 817,
#     "is_translation_enabled": false,
#     "utc_offset": -14400,
#     "statuses_count": 26901,
#     "description": "PhD DataScientist Astrophysicist, Top #BigData Influencer. Passions: #DataScience, #DataMining, Astroinformatics, #CitizenScience http://t.co/qYn8bft1fP",
#     "friends_count": 15224,
#     "location": "George Mason University",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/452157174769524737/cknjYfAC_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/534563976/1355112691",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg",
#     "screen_name": "KirkDBorne",
#     "lang": "en",
#     "profile_background_tile": true,
#     "favourites_count": 33769,
#     "name": "Kirk Borne",
#     "notifications": false,
#     "url": "http://t.co/tWlmevaWIF",
#     "created_at": "Fri Mar 23 16:35:17 +0000 2012",
#     "contributors_enabled": false,
#     "time_zone": "Eastern Time (US & Canada)",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Tue Oct 07 03:14:58 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1318985240,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/512672730395602944/yuJyI_3Z_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/6wxD9npeOZ",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://datasciencedojo.com/",
#        "display_url": "datasciencedojo.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": [
#       {
#        "url": "http://t.co/mRpEkKrS55",
#        "indices": [
#         19,
#         41
#        ],
#        "expanded_url": "http://datasciencedojo.com",
#        "display_url": "datasciencedojo.com"
#       },
#       {
#        "url": "http://t.co/qbUvcZlG6u",
#        "indices": [
#         47,
#         69
#        ],
#        "expanded_url": "http://facebook.com/datasciencedojo",
#        "display_url": "facebook.com/datasciencedojo"
#       },
#       {
#        "url": "http://t.co/BR1byQvYp3",
#        "indices": [
#         80,
#         102
#        ],
#        "expanded_url": "http://youtube.com/datasciencedojo",
#        "display_url": "youtube.com/datasciencedojo"
#       },
#       {
#        "url": "http://t.co/UwCqy444iD",
#        "indices": [
#         114,
#         136
#        ],
#        "expanded_url": "http://linkedin.com/company/data-science-dojo",
#        "display_url": "linkedin.com/company/data-s\u2026"
#       }
#      ]
#     }
#    },
#    "followers_count": 469,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "1318985240",
#    "profile_background_color": "C0DEED",
#    "listed_count": 25,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 919,
#    "description": "Visit Our Website: http://t.co/mRpEkKrS55\r\nFB: http://t.co/qbUvcZlG6u\r\nYouTube: http://t.co/BR1byQvYp3\r\nLinkedIn: http://t.co/UwCqy444iD",
#    "friends_count": 231,
#    "location": "Seattle, WA and Stanford, CA",
#    "profile_link_color": "F16022",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/512672730395602944/yuJyI_3Z_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1318985240/1404841793",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "DataScienceDojo",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 42,
#    "name": "Data Science Dojo",
#    "notifications": false,
#    "url": "http://t.co/6wxD9npeOZ",
#    "created_at": "Sun Mar 31 19:25:57 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Tue Oct 07 04:23:34 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "Top #DataScience Story: @ascheink: 'marriage maps @BuzzFeedNews @FiveThirtyEigh\u2026 http://t.co/OmSoug9G6h, see more http://t.co/WTyWm8qrOi",
#   "in_reply_to_status_id": null,
#   "id": 519341760921993217,
#   "favorite_count": 2,
#   "source": "<a href=\"http://tweetedtimes.com\" rel=\"nofollow\">The Tweeted Times Mobile</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 49853,
#      "indices": [
#       24,
#       33
#      ],
#      "id_str": "49853",
#      "screen_name": "ascheink",
#      "name": "Andrei Scheinkman"
#     },
#     {
#      "id": 1020058453,
#      "indices": [
#       50,
#       63
#      ],
#      "id_str": "1020058453",
#      "screen_name": "BuzzFeedNews",
#      "name": "BuzzFeed News"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       4,
#       16
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/WTyWm8qrOi",
#      "indices": [
#       114,
#       136
#      ],
#      "expanded_url": "http://tweetedtimes.com/mikepluta/data-science-tweeps?s=tnp",
#      "display_url": "tweetedtimes.com/mikepluta/data\u2026"
#     }
#    ],
#    "media": [
#     {
#      "source_status_id_str": "519244826085449730",
#      "expanded_url": "http://twitter.com/ascheink/status/519244826085449730/photo/1",
#      "display_url": "pic.twitter.com/OmSoug9G6h",
#      "url": "http://t.co/OmSoug9G6h",
#      "media_url_https": "https://pbs.twimg.com/media/BzS6atvIAAIMnbI.png",
#      "source_status_id": 519244826085449730,
#      "id_str": "519244825171066882",
#      "sizes": {
#       "small": {
#        "h": 493,
#        "resize": "fit",
#        "w": 340
#       },
#       "large": {
#        "h": 797,
#        "resize": "fit",
#        "w": 549
#       },
#       "medium": {
#        "h": 797,
#        "resize": "fit",
#        "w": 549
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       81,
#       103
#      ],
#      "type": "photo",
#      "id": 519244825171066882,
#      "media_url": "http://pbs.twimg.com/media/BzS6atvIAAIMnbI.png"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519341760921993217",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 15150700,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000657323963/7a2c02c57189cf6a7e73133150dde1f7_normal.jpeg",
#    "profile_sidebar_fill_color": "EFEFEF",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/FFACN2w5Ul",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.mikepluta.com",
#        "display_url": "mikepluta.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": [
#       {
#        "url": "http://t.co/8LvxHE2PwY",
#        "indices": [
#         109,
#         131
#        ],
#        "expanded_url": "http://www.aabdp.org",
#        "display_url": "aabdp.org"
#       }
#      ]
#     }
#    },
#    "followers_count": 735,
#    "profile_sidebar_border_color": "EEEEEE",
#    "id_str": "15150700",
#    "profile_background_color": "131516",
#    "listed_count": 45,
#    "is_translation_enabled": false,
#    "utc_offset": -21600,
#    "statuses_count": 5947,
#    "description": "Data Whisperer and Geek. #BI and #BigData Consultant. #MachineLearning, #PredictiveAnalytics, #R Enthusiast. http://t.co/8LvxHE2PwY Advisory Board, #BBBT member",
#    "friends_count": 1239,
#    "location": "Broomfield, CO",
#    "profile_link_color": "994F00",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/378800000657323963/7a2c02c57189cf6a7e73133150dde1f7_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/15150700/1397755457",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#    "screen_name": "mikepluta",
#    "lang": "en",
#    "profile_background_tile": true,
#    "favourites_count": 761,
#    "name": "Mike Pluta",
#    "notifications": false,
#    "url": "http://t.co/FFACN2w5Ul",
#    "created_at": "Tue Jun 17 21:31:18 +0000 2008",
#    "contributors_enabled": false,
#    "time_zone": "Mountain Time (US & Canada)",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Tue Oct 07 04:21:39 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "\"Data Science,it is not always realtime.  There may be delays.  To make it real-time, you need to stream the data.\" #datascience #scienceops",
#   "in_reply_to_status_id": null,
#   "id": 519340263601610752,
#   "favorite_count": 0,
#   "source": "<a href=\"http://bufferapp.com\" rel=\"nofollow\">Buffer</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       116,
#       128
#      ],
#      "text": "datascience"
#     },
#     {
#      "indices": [
#       129,
#       140
#      ],
#      "text": "scienceops"
#     }
#    ],
#    "urls": []
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 0,
#   "id_str": "519340263601610752",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": true,
#    "id": 14290932,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 43,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "14290932",
#    "profile_background_color": "C0DEED",
#    "listed_count": 0,
#    "is_translation_enabled": false,
#    "utc_offset": -28800,
#    "statuses_count": 93,
#    "description": "Data Scientist, Business Admin, Marketing Master, Internet Marketer, IT Engineer, Solutions Architect",
#    "friends_count": 51,
#    "location": "",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "wenmi01",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 1,
#    "name": "Rowen Remis R. Iral",
#    "notifications": false,
#    "url": null,
#    "created_at": "Thu Apr 03 06:38:48 +0000 2008",
#    "contributors_enabled": false,
#    "time_zone": "Alaska",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "lang": "en",
#   "created_at": "Tue Oct 07 04:15:42 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @KirkDBorne: Strategies to attack #BigData with #DataScience: http://t.co/Iee8hRSeO0 #abdsc via @DataScienceCtrl http://t.co/OOj0A1wMRW",
#   "in_reply_to_status_id": null,
#   "id": 519339766366871553,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 534563976,
#      "indices": [
#       3,
#       14
#      ],
#      "id_str": "534563976",
#      "screen_name": "KirkDBorne",
#      "name": "Kirk Borne"
#     },
#     {
#      "id": 393033324,
#      "indices": [
#       99,
#       115
#      ],
#      "id_str": "393033324",
#      "screen_name": "DataScienceCtrl",
#      "name": "Data Science Central"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       37,
#       45
#      ],
#      "text": "BigData"
#     },
#     {
#      "indices": [
#       51,
#       63
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       88,
#       94
#      ],
#      "text": "abdsc"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/Iee8hRSeO0",
#      "indices": [
#       65,
#       87
#      ],
#      "expanded_url": "http://bit.ly/1pUisbM",
#      "display_url": "bit.ly/1pUisbM"
#     }
#    ],
#    "media": [
#     {
#      "source_status_id_str": "519307476454604800",
#      "expanded_url": "http://twitter.com/KirkDBorne/status/519307476454604800/photo/1",
#      "display_url": "pic.twitter.com/OOj0A1wMRW",
#      "url": "http://t.co/OOj0A1wMRW",
#      "media_url_https": "https://pbs.twimg.com/media/BzTzZdSIcAALCiM.jpg",
#      "source_status_id": 519307476454604800,
#      "id_str": "519307475737407488",
#      "sizes": {
#       "large": {
#        "h": 469,
#        "resize": "fit",
#        "w": 777
#       },
#       "small": {
#        "h": 205,
#        "resize": "fit",
#        "w": 340
#       },
#       "medium": {
#        "h": 362,
#        "resize": "fit",
#        "w": 600
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       116,
#       138
#      ],
#      "type": "photo",
#      "id": 519307475737407488,
#      "media_url": "http://pbs.twimg.com/media/BzTzZdSIcAALCiM.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 5,
#   "id_str": "519339766366871553",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Strategies to attack #BigData with #DataScience: http://t.co/Iee8hRSeO0 #abdsc via @DataScienceCtrl http://t.co/OOj0A1wMRW",
#    "in_reply_to_status_id": null,
#    "id": 519307476454604800,
#    "favorite_count": 7,
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 393033324,
#       "indices": [
#        83,
#        99
#       ],
#       "id_str": "393033324",
#       "screen_name": "DataScienceCtrl",
#       "name": "Data Science Central"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        21,
#        29
#       ],
#       "text": "BigData"
#      },
#      {
#       "indices": [
#        35,
#        47
#       ],
#       "text": "DataScience"
#      },
#      {
#       "indices": [
#        72,
#        78
#       ],
#       "text": "abdsc"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/Iee8hRSeO0",
#       "indices": [
#        49,
#        71
#       ],
#       "expanded_url": "http://bit.ly/1pUisbM",
#       "display_url": "bit.ly/1pUisbM"
#      }
#     ],
#     "media": [
#      {
#       "expanded_url": "http://twitter.com/KirkDBorne/status/519307476454604800/photo/1",
#       "display_url": "pic.twitter.com/OOj0A1wMRW",
#       "url": "http://t.co/OOj0A1wMRW",
#       "media_url_https": "https://pbs.twimg.com/media/BzTzZdSIcAALCiM.jpg",
#       "id_str": "519307475737407488",
#       "sizes": {
#        "large": {
#         "h": 469,
#         "resize": "fit",
#         "w": 777
#        },
#        "small": {
#         "h": 205,
#         "resize": "fit",
#         "w": 340
#        },
#        "medium": {
#         "h": 362,
#         "resize": "fit",
#         "w": 600
#        },
#        "thumb": {
#         "h": 150,
#         "resize": "crop",
#         "w": 150
#        }
#       },
#       "indices": [
#        100,
#        122
#       ],
#       "type": "photo",
#       "id": 519307475737407488,
#       "media_url": "http://pbs.twimg.com/media/BzTzZdSIcAALCiM.jpg"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 5,
#    "id_str": "519307476454604800",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 534563976,
#     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/452157174769524737/cknjYfAC_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "http://t.co/tWlmevaWIF",
#         "indices": [
#          0,
#          22
#         ],
#         "expanded_url": "http://www.linkedin.com/in/kirkdborne",
#         "display_url": "linkedin.com/in/kirkdborne"
#        }
#       ]
#      },
#      "description": {
#       "urls": [
#        {
#         "url": "http://t.co/qYn8bft1fP",
#         "indices": [
#          130,
#          152
#         ],
#         "expanded_url": "http://kirkborne.net/",
#         "display_url": "kirkborne.net"
#        }
#       ]
#      }
#     },
#     "followers_count": 16372,
#     "profile_sidebar_border_color": "FFFFFF",
#     "id_str": "534563976",
#     "profile_background_color": "C0DEED",
#     "listed_count": 817,
#     "is_translation_enabled": false,
#     "utc_offset": -14400,
#     "statuses_count": 26901,
#     "description": "PhD DataScientist Astrophysicist, Top #BigData Influencer. Passions: #DataScience, #DataMining, Astroinformatics, #CitizenScience http://t.co/qYn8bft1fP",
#     "friends_count": 15224,
#     "location": "George Mason University",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/452157174769524737/cknjYfAC_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/534563976/1355112691",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg",
#     "screen_name": "KirkDBorne",
#     "lang": "en",
#     "profile_background_tile": true,
#     "favourites_count": 33769,
#     "name": "Kirk Borne",
#     "notifications": false,
#     "url": "http://t.co/tWlmevaWIF",
#     "created_at": "Fri Mar 23 16:35:17 +0000 2012",
#     "contributors_enabled": false,
#     "time_zone": "Eastern Time (US & Canada)",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Tue Oct 07 02:05:25 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 15365988,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/461260365670526977/Ahdsj0q__normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 72,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "15365988",
#    "profile_background_color": "C0DEED",
#    "listed_count": 0,
#    "is_translation_enabled": false,
#    "utc_offset": -25200,
#    "statuses_count": 508,
#    "description": "Design researcher for operating systems at Microsoft. Making people's lives better through research.",
#    "friends_count": 174,
#    "location": "Redmond, WA",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/461260365670526977/Ahdsj0q__normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "redhouse67",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 48,
#    "name": "Paula Bach",
#    "notifications": false,
#    "url": null,
#    "created_at": "Wed Jul 09 14:36:05 +0000 2008",
#    "contributors_enabled": false,
#    "time_zone": "Pacific Time (US & Canada)",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Tue Oct 07 04:13:43 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @KirkDBorne: Awesome visual summary of 270+ #DataViz tools &amp; resources\nhttp://t.co/IKe9d1D9u0 by @visualisingdata #DataScience http://t.\u2026",
#   "in_reply_to_status_id": null,
#   "id": 519338480384892928,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 534563976,
#      "indices": [
#       3,
#       14
#      ],
#      "id_str": "534563976",
#      "screen_name": "KirkDBorne",
#      "name": "Kirk Borne"
#     },
#     {
#      "id": 137712607,
#      "indices": [
#       104,
#       120
#      ],
#      "id_str": "137712607",
#      "screen_name": "visualisingdata",
#      "name": "Andy Kirk"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       47,
#       55
#      ],
#      "text": "DataViz"
#     },
#     {
#      "indices": [
#       121,
#       133
#      ],
#      "text": "DataScience"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/IKe9d1D9u0",
#      "indices": [
#       78,
#       100
#      ],
#      "expanded_url": "http://bit.ly/1wJr7yx",
#      "display_url": "bit.ly/1wJr7yx"
#     }
#    ],
#    "media": [
#     {
#      "source_status_id_str": "519324978266009600",
#      "expanded_url": "http://twitter.com/KirkDBorne/status/519324978266009600/photo/1",
#      "display_url": "pic.twitter.com/SawP4ZTqjG",
#      "url": "http://t.co/SawP4ZTqjG",
#      "media_url_https": "https://pbs.twimg.com/media/BzUDUM9IMAANpjn.jpg",
#      "source_status_id": 519324978266009600,
#      "id_str": "519324977641041920",
#      "sizes": {
#       "small": {
#        "h": 407,
#        "resize": "fit",
#        "w": 340
#       },
#       "large": {
#        "h": 1024,
#        "resize": "fit",
#        "w": 854
#       },
#       "medium": {
#        "h": 719,
#        "resize": "fit",
#        "w": 600
#       },
#       "thumb": {
#        "h": 150,
#        "resize": "crop",
#        "w": 150
#       }
#      },
#      "indices": [
#       143,
#       144
#      ],
#      "type": "photo",
#      "id": 519324977641041920,
#      "media_url": "http://pbs.twimg.com/media/BzUDUM9IMAANpjn.jpg"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 6,
#   "id_str": "519338480384892928",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Awesome visual summary of 270+ #DataViz tools &amp; resources\nhttp://t.co/IKe9d1D9u0 by @visualisingdata #DataScience http://t.co/SawP4ZTqjG",
#    "in_reply_to_status_id": null,
#    "id": 519324978266009600,
#    "favorite_count": 9,
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 137712607,
#       "indices": [
#        88,
#        104
#       ],
#       "id_str": "137712607",
#       "screen_name": "visualisingdata",
#       "name": "Andy Kirk"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        31,
#        39
#       ],
#       "text": "DataViz"
#      },
#      {
#       "indices": [
#        105,
#        117
#       ],
#       "text": "DataScience"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/IKe9d1D9u0",
#       "indices": [
#        62,
#        84
#       ],
#       "expanded_url": "http://bit.ly/1wJr7yx",
#       "display_url": "bit.ly/1wJr7yx"
#      }
#     ],
#     "media": [
#      {
#       "expanded_url": "http://twitter.com/KirkDBorne/status/519324978266009600/photo/1",
#       "display_url": "pic.twitter.com/SawP4ZTqjG",
#       "url": "http://t.co/SawP4ZTqjG",
# ...
#         "indices": [
#          130,
#          152
#         ],
#         "expanded_url": "http://kirkborne.net/",
#         "display_url": "kirkborne.net"
#        }
#       ]
#      }
#     },
#     "followers_count": 16372,
#     "profile_sidebar_border_color": "FFFFFF",
#     "id_str": "534563976",
#     "profile_background_color": "C0DEED",
#     "listed_count": 817,
#     "is_translation_enabled": false,
#     "utc_offset": -14400,
#     "statuses_count": 26901,
#     "description": "PhD DataScientist Astrophysicist, Top #BigData Influencer. Passions: #DataScience, #DataMining, Astroinformatics, #CitizenScience http://t.co/qYn8bft1fP",
#     "friends_count": 15224,
#     "location": "George Mason University",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/452157174769524737/cknjYfAC_normal.jpeg",
#     "following": false,
#     "geo_enabled": true,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/534563976/1355112691",
#     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000110442114/094a0b4d38b70e3871a1bda7d7fe2341.jpeg",
#     "screen_name": "KirkDBorne",
#     "lang": "en",
#     "profile_background_tile": true,
#     "favourites_count": 33769,
#     "name": "Kirk Borne",
#     "notifications": false,
#     "url": "http://t.co/tWlmevaWIF",
#     "created_at": "Fri Mar 23 16:35:17 +0000 2012",
#     "contributors_enabled": false,
#     "time_zone": "Eastern Time (US & Canada)",
#     "protected": false,
#     "default_profile": false,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Mon Oct 06 21:08:28 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": {
#     "full_name": "Woodlawn, MD",
#     "url": "https://api.twitter.com/1.1/geo/id/bf64a5dd9b5f1cf2.json",
#     "country": "United States",
#     "place_type": "city",
#     "bounding_box": {
#      "type": "Polygon",
#      "coordinates": [
#       [
#        [
#         -76.915396,
#         38.938828
#        ],
#        [
#         -76.711092,
#         38.938828
#        ],
#        [
#         -76.711092,
#         39.327477
#        ],
#        [
#         -76.915396,
#         39.327477
#        ]
#       ]
#      ]
#     },
#     "contained_within": [],
#     "country_code": "US",
#     "attributes": {},
#     "id": "bf64a5dd9b5f1cf2",
#     "name": "Woodlawn"
#    },
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 618252430,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/2508005057/psgpd0vewupd79yvxwhn_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/M5YQsBGvGi",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "https://www.linkedin.com/profile/view?id=173169977&trk=nav_responsive_tab_profile",
#        "display_url": "linkedin.com/profile/view?i\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 83,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "618252430",
#    "profile_background_color": "C0DEED",
#    "listed_count": 7,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 536,
#    "description": "@CentraleLyon student. Follow me if you're interested in #Machinelearning and #bigdata !",
#    "friends_count": 171,
#    "location": "Lyon, France",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/2508005057/psgpd0vewupd79yvxwhn_normal.jpeg",
#    "following": false,
#    "geo_enabled": true,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "anil_nara",
#    "lang": "fr",
#    "profile_background_tile": false,
#    "favourites_count": 42,
#    "name": "Anil Narassiguin",
#    "notifications": false,
#    "url": "https://t.co/M5YQsBGvGi",
#    "created_at": "Mon Jun 25 16:52:01 +0000 2012",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 22:35:56 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "See Spark Run on NoSQL, DataStax Says http://t.co/QnAHx8j42z #DataScience #BigData",
#   "in_reply_to_status_id": null,
#   "id": 519253305588187136,
#   "favorite_count": 1,
#   "source": "<a href=\"http://bufferapp.com\" rel=\"nofollow\">Buffer</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       61,
#       73
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       74,
#       82
#      ],
#      "text": "BigData"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/QnAHx8j42z",
#      "indices": [
#       38,
#       60
#      ],
#      "expanded_url": "http://buff.ly/1xaXk1M",
#      "display_url": "buff.ly/1xaXk1M"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "519253305588187136",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 2207639850,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000771090721/823ecaf05d7e927b220471b676cbfc4c_normal.jpeg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/MAPL4KknTq",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://districtdatalabs.com",
#        "display_url": "districtdatalabs.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 226,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "2207639850",
#    "profile_background_color": "C0DEED",
#    "listed_count": 23,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 638,
#    "description": "#DataScience workshops, courses, and projects designed to enhance your technical and analytical skills.  #BigData #DataDC #MachineLearning #Analytics",
#    "friends_count": 63,
#    "location": "Washington, DC",
#    "profile_link_color": "0084B4",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/378800000771090721/823ecaf05d7e927b220471b676cbfc4c_normal.jpeg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "DistrictDataLab",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 55,
#    "name": "District Data Labs",
#    "notifications": false,
#    "url": "http://t.co/MAPL4KknTq",
#    "created_at": "Thu Nov 21 18:42:01 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 22:30:09 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  {
#   "contributors": null,
#   "truncated": false,
#   "text": "RT @GilPress: Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#   "in_reply_to_status_id": null,
#   "id": 519252477263511552,
#   "favorite_count": 0,
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "retweeted": false,
#   "coordinates": null,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [
#     {
#      "id": 49383389,
#      "indices": [
#       3,
#       12
#      ],
#      "id_str": "49383389",
#      "screen_name": "GilPress",
#      "name": "Gil Press"
#     },
#     {
#      "id": 91478624,
#      "indices": [
#       92,
#       99
#      ],
#      "id_str": "91478624",
#      "screen_name": "Forbes",
#      "name": "Forbes"
#     }
#    ],
#    "hashtags": [
#     {
#      "indices": [
#       100,
#       112
#      ],
#      "text": "DataScience"
#     },
#     {
#      "indices": [
#       113,
#       129
#      ],
#      "text": "MachineLearning"
#     },
#     {
#      "indices": [
#       130,
#       137
#      ],
#      "text": "Hadoop"
#     }
#    ],
#    "urls": [
#     {
#      "url": "http://t.co/E65MNxTCnu",
#      "indices": [
#       65,
#       87
#      ],
#      "expanded_url": "http://onforb.es/1xgYoBb",
#      "display_url": "onforb.es/1xgYoBb"
#     }
#    ]
#   },
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 5,
#   "id_str": "519252477263511552",
#   "favorited": false,
#   "retweeted_status": {
#    "contributors": null,
#    "truncated": false,
#    "text": "Top Ten Most Funded Big Data Startups October 2014 http://t.co/E65MNxTCnu via @forbes #DataScience #MachineLearning #Hadoop",
#    "in_reply_to_status_id": null,
#    "id": 519153377641369600,
#    "favorite_count": 2,
#    "source": "<a href=\"https://dev.twitter.com/docs/tfw\" rel=\"nofollow\">Twitter for Websites</a>",
#    "retweeted": false,
#    "coordinates": null,
#    "entities": {
#     "symbols": [],
#     "user_mentions": [
#      {
#       "id": 91478624,
#       "indices": [
#        78,
#        85
#       ],
#       "id_str": "91478624",
#       "screen_name": "Forbes",
#       "name": "Forbes"
#      }
#     ],
#     "hashtags": [
#      {
#       "indices": [
#        86,
#        98
#       ],
#       "text": "DataScience"
#      },
#      {
#       "indices": [
#        99,
#        115
#       ],
#       "text": "MachineLearning"
#      },
#      {
#       "indices": [
#        116,
#        123
#       ],
#       "text": "Hadoop"
#      }
#     ],
#     "urls": [
#      {
#       "url": "http://t.co/E65MNxTCnu",
#       "indices": [
#        51,
#        73
#       ],
#       "expanded_url": "http://onforb.es/1xgYoBb",
#       "display_url": "onforb.es/1xgYoBb"
#      }
#     ]
#    },
#    "in_reply_to_screen_name": null,
#    "in_reply_to_user_id": null,
#    "retweet_count": 5,
#    "id_str": "519153377641369600",
#    "favorited": false,
#    "user": {
#     "follow_request_sent": false,
#     "profile_use_background_image": true,
#     "default_profile_image": false,
#     "id": 49383389,
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "verified": false,
#     "profile_text_color": "333333",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3363469318/0ad694a54549d193be036ef6ad5d88be_normal.jpeg",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "entities": {
#      "description": {
#       "urls": [
#        {
#         "url": "http://t.co/Yi3mq5lLo9",
#         "indices": [
#          78,
#          100
#         ],
#         "expanded_url": "http://www.forbes.com/sites/gilpress/",
#         "display_url": "forbes.com/sites/gilpress/"
#        },
#        {
#         "url": "http://t.co/ZYLDmDfYPj",
#         "indices": [
#          105,
#          127
#         ],
#         "expanded_url": "http://whatsthebigdata.com/",
#         "display_url": "whatsthebigdata.com"
#        },
#        {
#         "url": "http://t.co/6MZY64G2bG",
#         "indices": [
#          130,
#          152
#         ],
#         "expanded_url": "http://infostory.com/",
#         "display_url": "infostory.com"
#        }
#       ]
#      }
#     },
#     "followers_count": 4340,
#     "profile_sidebar_border_color": "C0DEED",
#     "id_str": "49383389",
#     "profile_background_color": "C0DEED",
#     "listed_count": 355,
#     "is_translation_enabled": false,
#     "utc_offset": -14400,
#     "statuses_count": 11800,
#     "description": "I launched the #BigData conversation; writing, research, marketing services;  http://t.co/Yi3mq5lLo9 \r\n\r\nhttp://t.co/ZYLDmDfYPj & http://t.co/6MZY64G2bG",
#     "friends_count": 411,
#     "location": "Boston",
#     "profile_link_color": "0084B4",
#     "profile_image_url": "http://pbs.twimg.com/profile_images/3363469318/0ad694a54549d193be036ef6ad5d88be_normal.jpeg",
#     "following": false,
#     "geo_enabled": false,
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "screen_name": "GilPress",
#     "lang": "en",
#     "profile_background_tile": false,
#     "favourites_count": 342,
#     "name": "Gil Press",
#     "notifications": false,
#     "url": null,
#     "created_at": "Sun Jun 21 18:16:39 +0000 2009",
#     "contributors_enabled": false,
#     "time_zone": "Eastern Time (US & Canada)",
#     "protected": false,
#     "default_profile": true,
#     "is_translator": false
#    },
#    "geo": null,
#    "in_reply_to_user_id_str": null,
#    "possibly_sensitive": false,
#    "lang": "en",
#    "created_at": "Mon Oct 06 15:53:05 +0000 2014",
#    "in_reply_to_status_id_str": null,
#    "place": null,
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    }
#   },
#   "user": {
#    "follow_request_sent": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 1270951124,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/885504144/5bbcc782aede2fc3fd86a5d459857caf.jpeg",
#    "verified": false,
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/476309258544226304/pg1PvSc9_normal.png",
#    "profile_sidebar_fill_color": "EFEFEF",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/GL0DjMjrMu",
#        "indices": [
#         0,
#         22
#        ],
#        "expanded_url": "http://www.bigdata4success.com",
#        "display_url": "bigdata4success.com"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 590,
#    "profile_sidebar_border_color": "000000",
#    "id_str": "1270951124",
#    "profile_background_color": "131516",
#    "listed_count": 30,
#    "is_translation_enabled": false,
#    "utc_offset": 7200,
#    "statuses_count": 1412,
#    "description": "Tu recurso online sobre big data en espa\u00f1ol",
#    "friends_count": 813,
#    "location": "Espa\u00f1a",
#    "profile_link_color": "009999",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/476309258544226304/pg1PvSc9_normal.png",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1270951124/1402395884",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/885504144/5bbcc782aede2fc3fd86a5d459857caf.jpeg",
#    "screen_name": "BD4S_1",
#    "lang": "es",
#    "profile_background_tile": true,
#    "favourites_count": 172,
#    "name": "big data 4 success",
#    "notifications": false,
#    "url": "http://t.co/GL0DjMjrMu",
#    "created_at": "Fri Mar 15 23:24:01 +0000 2013",
#    "contributors_enabled": false,
#    "time_zone": "Amsterdam",
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Mon Oct 06 22:26:52 +0000 2014",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  }
# ]

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:5], indent=1) 
print json.dumps(hashtags[0:5], indent=1)
print json.dumps(words[0:5], indent=1)
# Out:
# [
#  "RT @Terry_Timko: Now #DataDriven\n... how @AIG Moved 2 Evidence-Based Decision Making\nhttp://t.co/f6FWot3Lxw #datascience #bigdata",
#  "RT @thinkBigA: Don't miss @thinkBigA's Sr. #DataScientist Field Cady on \"#Python for #DataScience\" tomorrow at @pawcon Boston 2014 http://t\u2026",
#  "RT @Terry_Timko @eBay optimizes  listing 4 sellers thru #DataScience\nhttp://t.co/n1xWYt39xM http://t.co/70EDBK05ng #retail #ecommerce",
#  "RT @KirkDBorne: Awesome visual summary of 270+ #DataViz tools &amp; resources\nhttp://t.co/IKe9d1D9u0 by @visualisingdata #DataScience http://t.\u2026",
#  "Top #DataScience Story: @ascheink: 'marriage maps @BuzzFeedNews @FiveThirtyEigh\u2026 http://t.co/OmSoug9G6h, see more http://t.co/WTyWm8qrOi"
# ]
# [
#  "Terry_Timko",
#  "AiG",
#  "thinkBigA",
#  "thinkBigA",
#  "pawcon"
# ]
# [
#  "DataDriven",
#  "datascience",
#  "bigdata",
#  "DataScientist",
#  "Python"
# ]
# [
#  "RT",
#  "@Terry_Timko:",
#  "Now",
#  "#DataDriven",
#  "..."
# ]

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print c.most_common()[:10] # top 10
    print
# Out:
# [(u'RT', 54), (u'#DataScience', 49), (u'to', 29), (u'#datascience', 29), (u'Data', 28), (u'#BigData', 25), (u'and', 22), (u'the', 21), (u'of', 20), (u'@KirkDBorne:', 16)]
#
# [(u'KirkDBorne', 16), (u'DataScienceCtrl', 10), (u'visualisingdata', 7), (u'dimkots', 6), (u'DataRobot', 4), (u'mark_torr', 3), (u'GilPress', 3), (u'CamacConsulting', 3), (u'AngelaZutavern', 3), (u'thinkBigA', 2)]
#
# [(u'DataScience', 67), (u'datascience', 33), (u'BigData', 29), (u'Analytics', 11), (u'bigdata', 10), (u'abdsc', 10), (u'analytics', 9), (u'DataViz', 9), (u'Hadoop', 6), (u'Statistics', 5)]

# %% [markdown]
# ### Exercise 2
# ##### What are the search results for #machinelearning?
# ##### Which words, screen_names and hashtags are most common?
#
# ### Bonus Questions
# ##### Which hashtags are most common between #machinelearning and #datascience?
# ##### Search the most popular data science hashtags and determine what topics are trending the most across the most popular data science hastags?
# ##### Determine the most prolific screen_names for data science and find out who they are?
