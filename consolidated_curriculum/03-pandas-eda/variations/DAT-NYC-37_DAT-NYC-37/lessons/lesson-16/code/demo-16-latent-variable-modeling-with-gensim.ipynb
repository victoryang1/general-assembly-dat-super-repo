# %% [markdown]
# # Demo 16 Latent Variable Modeling with `gensim`

# %% [markdown]
# `gensim` (http://radimrehurek.com/gensim) is a library of language processing tools focused on latent variable models of text.

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_extraction
from gensim import matutils, models

pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# The data is about sentiments on Amazon reviews.

# %%
reviews = []
sentiments = []

with open(os.path.join('..', 'datasets', 'amazon-reviews.txt')) as f:
    for line in f.readlines():
        line = line.strip('\n')
        review, sentiment = line.split('\t')
        sentiment = np.nan if sentiment == '' else int(sentiment)

        reviews.append(review.lower())
        sentiments.append(sentiment)

df = pd.DataFrame({'review': reviews, 'sentiment': sentiments})

# %%
df.head()
# Out:
#                                               review  sentiment
# 0  i try not to adjust the volume setting to avoi...        NaN
# 1  so there is no way for me to plug it in here i...        0.0
# 2                        good case, excellent value.        1.0
# 3        i thought motorola made reliable products!.        NaN
# 4                         battery for motorola razr.        NaN

# %%
df.dropna(inplace = True) # Let's drop the NaN

# %%
df.head()
# Out:
#                                               review  sentiment
# 0  i try not to adjust the volume setting to avoi...        NaN
# 1  so there is no way for me to plug it in here i...        0.0
# 2                        good case, excellent value.        1.0
# 3        i thought motorola made reliable products!.        NaN
# 4                         battery for motorola razr.        NaN

# %% [markdown]
# ## LDA with `gensim`

# %% [markdown]
# ### Let's first translate a set of documents (articles) into a matrix representation with a row per document and a column per feature (word or n-gram)

# %%
vectorizer = feature_extraction.text.CountVectorizer(stop_words = 'english')

# %%
documents = vectorizer.fit_transform(df.review)

# %%
# Let's now build a mapping of numerical ID to word

id2word = dict(enumerate(vectorizer.get_feature_names()))

# %%
id2word
# Out:
# {0: u'00',
#  1: u'000',
#  2: u'00332',
#  3: u'00pm',
#  4: u'01',
#  5: u'02',
#  6: u'04',
#  7: u'05',
#  8: u'06',
#  9: u'07',
#  10: u'08',
#  11: u'09',
#  12: u'093744',
#  13: u'10',
#  14: u'100',
#  15: u'1000',
#  16: u'1000mah',
#  17: u'100k',
#  18: u'100m',
#  19: u'102',
#  20: u'105',
#  21: u'109',
#  22: u'10meters',
#  23: u'10x',
#  24: u'11',
#  25: u'110',
#  26: u'1100',
#  27: u'1100mah',
#  28: u'112',
#  29: u'112kbps',
#  30: u'115',
#  31: u'118',
#  32: u'11mb',
#  33: u'11w',
#  34: u'12',
#  35: u'120',
#  36: u'121',
#  37: u'128',
#  38: u'128k',
#  39: u'128mb',
#  40: u'12v',
#  41: u'13',
#  42: u'1300',
#  43: u'1301',
#  44: u'14',
#  45: u'15',
#  46: u'150',
#  47: u'15g',
#  48: u'15th',
#  49: u'16',
#  50: u'1650sq',
#  51: u'16th',
#  52: u'17',
#  53: u'172x220',
#  54: u'175',
#  55: u'18',
#  56: u'1800',
#  57: u'1800beholy',
#  58: u'1800mah',
#  59: u'181',
#  60: u'19',
#  61: u'1900',
#  62: u'19005',
#  63: u'1945',
#  64: u'1955',
#  65: u'1999',
#  66: u'1gb',
#  67: u'1st',
#  68: u'1x',
#  69: u'20',
#  70: u'200',
#  71: u'2000',
#  72: u'2002',
#  73: u'2003',
#  74: u'2004',
#  75: u'2005',
#  76: u'2006',
#  77: u'2007',
#  78: u'2008',
#  79: u'2008update',
#  80: u'200mhz',
#  81: u'201',
#  82: u'2011',
#  83: u'2012when',
#  84: u'20912',
#  85: u'21',
#  86: u'2125',
#  87: u'215',
#  88: u'2160',
#  89: u'2169011',
#  90: u'22',
#  91: u'225',
#  92: u'2255',
#  93: u'22nd',
#  94: u'23',
#  95: u'24',
#  96: u'240',
#  97: u'2400mah',
#  98: u'2481',
#  99: u'25',
#  100: u'250',
#  101: u'250v',
#  102: u'25k',
#  103: u'25th',
#  104: u'26',
#  105: u'260',
#  106: u'269',
#  107: u'26th',
#  108: u'27',
#  109: u'270',
#  110: u'2700',
#  111: u'29',
#  112: u'29318ge1',
#  113: u'299',
#  114: u'2gb',
#  115: u'2mb',
#  116: u'2mp',
#  117: u'2nd',
#  118: u'2to3',
#  119: u'2x',
#  120: u'30',
#  121: u'300',
#  122: u'303',
#  123: u'3035',
#  124: u'305',
#  125: u'30mins',
#  126: u'30secs',
#  127: u'30usd',
#  128: u'31',
#  129: u'3125',
#  130: u'31st',
#  131: u'32',
#  132: u'320',
#  133: u'320k',
#  134: u'3220',
#  135: u'325',
#  136: u'32kbps',
#  137: u'33',
#  138: u'330',
#  139: u'335',
#  140: u'3360',
#  141: u'3390',
#  142: u'34',
#  143: u'340',
#  144: u'342',
#  145: u'35',
#  146: u'350',
#  147: u'3588i',
#  148: u'3595',
#  149: u'35mm',
#  150: u'36',
#  151: u'360',
#  152: u'3650',
#  153: u'375',
#  154: u'38718',
#  155: u'39',
#  156: u'3d',
#  157: u'3g',
#  158: u'3gp',
#  159: u'3gs',
#  160: u'3mpixel',
#  161: u'3o',
#  162: u'3r',
#  163: u'3rd',
#  164: u'3vm',
#  165: u'3x',
#  166: u'40',
#  167: u'400',
#  168: u'40ft',
#  169: u'411',
#  170: u'42',
#  171: u'44',
#  172: u'449',
#  173: u'45',
#  174: u'45mph',
#  175: u'47',
#  176: u'48',
#  177: u'480',
#  178: u'49',
#  179: u'4900',
#  180: u'4920',
#  181: u'4c',
#  182: u'4g',
#  183: u'4gb',
#  184: u'4gig',
#  185: u'4s',
#  186: u'4th',
#  187: u'4the',
#  188: u'4x',
#  189: u'50',
#  190: u'500',
#  191: u'5020',
#  192: u'509',
#  193: u'50x',
#  194: u'510',
#  195: u'510slplus',
#  196: u'512mb',
#  197: u'517',
#  198: u'520',
#  199: u'5300',
#  200: u'5320',
#  201: u'55',
#  202: u'550',
#  203: u'5500',
#  204: u'551',
#  205: u'55520',
#  206: u'5600',
#  207: u'5856',
#  208: u'59',
#  209: u'590a',
#  210: u'5bar',
#  211: u'5c',
#  212: u'5d',
#  213: u'5mm',
#  214: u'5mmi',
#  215: u'5mpixels',
#  216: u'5oz',
#  217: u'5rc',
#  218: u'5th',
#  219: u'60',
#  220: u'600',
#  221: u'600mah',
#  222: u'6010',
#  223: u'6030',
#  224: u'6061',
#  225: u'6080',
#  226: u'60gb',
#  227: u'61',
#  228: u'610',
#  229: u'6100',
#  230: u'6101',
#  231: u'6102',
#  232: u'6103',
#  233: u'6131',
#  234: u'616',
#  235: u'6160',
#  236: u'6165i',
#  237: u'6200',
#  238: u'6205',
#  239: u'6210',
#  240: u'6225',
#  241: u'6230',
#  242: u'6233',
#  243: u'6310i',
#  244: u'6315',
#  245: u'64',
#  246: u'640',
#  247: u'645',
#  248: u'64k',
#  249: u'64mb',
#  250: u'65',
#  251: u'650',
#  252: u'6515',
#  253: u'655',
#  254: u'6555',
#  255: u'6600',
#  256: u'665',
#  257: u'6650',
#  258: u'6700',
#  259: u'680',
#  260: u'6800',
#  261: u'690',
#  262: u'6c',
#  263: u'70',
#  264: u'700',
#  265: u'700p',
#  266: u'700w',
#  267: u'700wx',
#  268: u'700wxphone',
#  269: u'7050',
#  270: u'70mb',
#  271: u'71',
#  272: u'7100',
#  273: u'7100t',
#  274: u'72',
#  275: u'720',
#  276: u'720i',
#  277: u'720mah',
#  278: u'7250',
#  279: u'7300',
#  280: u'75',
#  281: u'750',
#  282: u'755p',
#  283: u'7575',
#  284: u'79',
#  285: u'7962',
#  286: u'7inch',
#  287: u'7th',
#  288: u'7v',
#  289: u'7xx',
#  290: u'80',
#  291: u'800',
#  292: u'800i',
#  293: u'8100',
#  294: u'810i',
#  295: u'8125',
#  296: u'8130',
#  297: u'820',
#  298: u'8200',
#  299: u'8260',
#  300: u'8290',
#  301: u'83',
#  302: u'8300',
#  303: u'8320',
#  304: u'8330',
#  305: u'850',
#  306: u'8525',
#  307: u'8530',
#  308: u'8550',
#  309: u'86',
#  310: u'8610',
#  311: u'8700',
#  312: u'8700c',
#  313: u'8700g',
#  314: u'8703',
#  315: u'88',
#  316: u'880',
#  317: u'8800',
#  318: u'8801',
#  319: u'887',
#  320: u'89',
#  321: u'8920',
#  322: u'8940',
#  323: u'8gb',
#  324: u'8mb',
#  325: u'8th',
#  326: u'90',
#  327: u'900',
#  328: u'910',
#  329: u'9100',
#  330: u'910a',
#  331: u'911',
#  332: u'92',
#  333: u'920',
#  334: u'925',
#  335: u'95',
#  336: u'950',
#  337: u'96',
#  338: u'97',
#  339: u'975',
#  340: u'98shippingnew',
#  341: u'99',
#  342: u'9month',
#  343: u'9q',
#  344: u'a1',
#  345: u'a1200',
#  346: u'a120s',
#  347: u'a125s',
#  348: u'a210',
#  349: u'a2dp',
#  350: u'a43',
#  351: u'a460',
#  352: u'a500',
#  353: u'a640',
#  354: u'a670',
#  355: u'a680',
#  356: u'a707',
#  357: u'a767',
#  358: u'a900',
#  359: u'a920',
#  360: u'a940',
#  361: u'a950',
#  362: u'a990',
#  363: u'aa',
#  364: u'aaa',
#  365: u'aac',
#  366: u'aacute',
#  367: u'aain',
#  368: u'abdate',
#  369: u'aberration',
#  370: u'abhor',
#  371: u'abilities',
#  372: u'ability',
#  373: u'able',
#  374: u'abound',
#  375: u'abscence',
#  376: u'absolute',
#  377: u'absolutel',
#  378: u'absolutely',
#  379: u'absurd',
#  380: u'abuse',
#  381: u'abysmal',
#  382: u'ac',
#  383: u'accent',
#  384: u'accept',
#  385: u'acceptable',
#  386: u'accepting',
#  387: u'access',
#  388: u'accessable',
#  389: u'accesses',
#  390: u'accessible',
#  391: u'accessing',
#  392: u'accessories',
#  393: u'accessory',
#  394: u'accessoryone',
#  395: u'accessoryonecondition',
#  396: u'accident',
#  397: u'accidental',
#  398: u'accidentally',
#  399: u'accidently',
#  400: u'accommodate',
#  401: u'accommodating',
#  402: u'accomodating',
#  403: u'accompanied',
#  404: u'accomplish',
#  405: u'accomplished',
#  406: u'accord',
#  407: u'according',
#  408: u'account',
#  409: u'accounts',
#  410: u'acct',
#  411: u'accumulates',
#  412: u'accurate',
#  413: u'accurately',
#  414: u'accustomed',
#  415: u'ace',
#  416: u'acess',
#  417: u'acessing',
#  418: u'acessories',
#  419: u'achieve',
#  420: u'achieving',
#  421: u'acoustibuds',
#  422: u'acquired',
#  423: u'acrylic',
#  424: u'act',
#  425: u'acting',
#  426: u'action',
#  427: u'activate',
#  428: u'activated',
#  429: u'activates',
#  430: u'activatethrice',
#  431: u'activating',
#  432: u'activation',
#  433: u'active',
#  434: u'activesync',
#  435: u'activity',
#  436: u'acts',
#  437: u'actual',
#  438: u'actually',
#  439: u'acutally',
#  440: u'ad',
#  441: u'adapt',
#  442: u'adaptable',
#  443: u'adapter',
#  444: u'adapters',
#  445: u'adaptor',
#  446: u'adaptors',
#  447: u'adaquate',
#  448: u'adavertised',
#  449: u'add',
#  450: u'added',
#  451: u'adding',
#  452: u'addition',
#  453: u'additional',
#  454: u'additionally',
#  455: u'address',
#  456: u'addressed',
#  457: u'addresses',
#  458: u'adds',
#  459: u'addvertised',
#  460: u'adequate',
#  461: u'adequately',
#  462: u'adhesive',
#  463: u'aditional',
#  464: u'adjacent',
#  465: u'adjust',
#  466: u'adjustable',
#  467: u'adjusted',
#  468: u'adjusting',
#  469: u'adjustment',
#  470: u'adjustments',
#  471: u'adjusts',
#  472: u'administrator',
#  473: u'admit',
#  474: u'admitted',
#  475: u'adobe',
#  476: u'adorable',
#  477: u'adore',
#  478: u'adpater',
#  479: u'ads',
#  480: u'adt',
#  481: u'adult',
#  482: u'adustable',
#  483: u'advance',
#  484: u'advanced',
#  485: u'advantage',
#  486: u'adverstised',
#  487: u'advertise',
#  488: u'advertised',
#  489: u'advertisement',
#  490: u'advertisements',
#  491: u'advertising',
#  492: u'advertisment',
#  493: u'advetisement',
#  494: u'advice',
#  495: u'advise',
#  496: u'advises',
#  497: u'aesthetically',
#  498: u'aesthetics',
#  499: u'afer',
#  500: u'affected',
#  501: u'afford',
#  502: u'affordable',
#  503: u'affords',
#  504: u'afraid',
#  505: u'africa',
#  506: u'afterall',
#  507: u'aftermarket',
#  508: u'afterthought',
#  509: u'aftertrying',
#  510: u'afterward',
#  511: u'againultra',
#  512: u'age',
#  513: u'aged',
#  514: u'agey',
#  515: u'aggie',
#  516: u'aggravating',
#  517: u'aggravation',
#  518: u'agian',
#  519: u'ago',
#  520: u'agonizing',
#  521: u'agravated',
#  522: u'agravation',
#  523: u'agree',
#  524: u'agreed',
#  525: u'agreement',
#  526: u'ah',
#  527: u'ahead',
#  528: u'ahhhs',
#  529: u'ahora',
#  530: u'ahve',
#  531: u'aid',
#  532: u'aim',
#  533: u'ain',
#  534: u'air',
#  535: u'airplane',
#  536: u'airplanes',
#  537: u'airport',
#  538: u'airports',
#  539: u'airtime',
#  540: u'airwaves',
#  541: u'airy',
#  542: u'ajstudio',
#  543: u'aka',
#  544: u'al',
#  545: u'alabama',
#  546: u'alarm',
#  547: u'alarms',
#  548: u'alaska',
#  549: u'albeit',
#  550: u'album',
#  551: u'alcohol',
#  552: u'alert',
#  553: u'ali',
#  554: u'alias',
#  555: u'aligned',
#  556: u'alignment',
#  557: u'alike',
#  558: u'aliph',
#  559: u'alittle',
#  560: u'alive',
#  561: u'alleviate',
#  562: u'allot',
#  563: u'alloted',
#  564: u'allotted',
#  565: u'allow',
#  566: u'allowed',
#  567: u'allowing',
#  568: u'allows',
#  569: u'allright',
#  570: u'alltel',
#  571: u'alltogether',
#  572: u'alot',
#  573: u'alow',
#  574: u'alpha',
#  575: u'alright',
#  576: u'alteration',
#  577: u'alternate',
#  578: u'alternately',
#  579: u'alternative',
#  580: u'alternatives',
#  581: u'altho',
#  582: u'althought',
#  583: u'altogether',
#  584: u'aluminum',
#  585: u'amaizing',
#  586: u'amaozons',
#  587: u'amaze',
#  588: u'amazed',
#  589: u'amazing',
#  590: u'amazingly',
#  591: u'amazingy',
#  592: u'amazon',
#  593: u'amazons',
#  594: u'amber',
#  595: u'ambient',
#  596: u'amenities',
#  597: u'america',
#  598: u'american',
#  599: u'amfm',
#  600: u'amigo',
#  601: u'amoled',
#  602: u'amounts',
#  603: u'amp',
#  604: u'ample',
#  605: u'ampleflier',
#  606: u'amplification',
#  607: u'amplified',
#  608: u'amplifier',
#  609: u'amplifies',
#  610: u'amps',
#  611: u'analog',
#  612: u'anatomy',
#  613: u'anchor',
#  614: u'andf',
#  615: u'andn',
#  616: u'android',
#  617: u'andy',
#  618: u'anf',
#  619: u'angeles',
#  620: u'angle',
#  621: u'angles',
#  622: u'angry',
#  623: u'angst',
#  624: u'anil',
#  625: u'animal',
#  626: u'animated',
#  627: u'animations',
#  628: u'announcemenet',
#  629: u'announcements',
#  630: u'annoyance',
#  631: u'annoyances',
#  632: u'annoyed',
#  633: u'annoying',
#  634: u'annoyingly',
#  635: u'anoying',
#  636: u'answer',
#  637: u'answered',
#  638: u'answering',
#  639: u'answers',
#  640: u'ant',
#  641: u'antena',
#  642: u'antenna',
#  643: u'antennae',
#  644: u'anti',
#  645: u'anticipated',
#  646: u'antique',
#  647: u'antonio',
#  648: u'antonline',
#  649: u'antronics',
#  650: u'anybody',
#  651: u'anymore',
#  652: u'anytime',
#  653: u'anyting',
#  654: u'anyways',
#  655: u'aout',
#  656: u'aparce',
#  657: u'apart',
#  658: u'apartment',
#  659: u'aperture',
#  660: u'apiece',
#  661: u'apologize',
#  662: u'apologized',
#  663: u'apologizes',
#  664: u'apology',
#  665: u'appalled',
#  666: u'apparent',
#  667: u'apparently',
#  668: u'appeal',
#  669: u'appealing',
#  670: u'appeals',
#  671: u'appear',
#  672: u'appearance',
#  673: u'appeared',
#  674: u'appearence',
#  675: u'appears',
#  676: u'appereance',
#  677: u'apple',
#  678: u'application',
#  679: u'applications',
#  680: u'applied',
#  681: u'applies',
#  682: u'applifies',
#  683: u'apply',
#  684: u'applying',
#  685: u'appointment',
#  686: u'appointments',
#  687: u'appologized',
#  688: u'appose',
#  689: u'appreciate',
#  690: u'appreciated',
#  691: u'apprehensive',
#  692: u'approach',
#  693: u'appropriate',
#  694: u'approved',
#  695: u'approx',
#  696: u'approximately',
#  697: u'apps',
#  698: u'april',
#  699: u'apt',
#  700: u'aquos',
#  701: u'arch',
#  702: u'area',
#  703: u'areas',
#  704: u'aren',
#  705: u'arent',
#  706: u'ares',
#  707: u'arggggggggg',
#  708: u'argued',
#  709: u'arguing',
#  710: u'arm',
#  711: u'armband',
#  712: u'armies',
#  713: u'armor',
#  714: u'arose',
#  715: u'arrangement',
#  716: u'arrangements',
#  717: u'arrests',
#  718: u'arrival',
#  719: u'arrive',
#  720: u'arrived',
#  721: u'arrives',
#  722: u'arrow',
#  723: u'arrows',
#  724: u'art',
#  725: u'article',
#  726: u'articles',
#  727: u'articulo',
#  728: u'artifact',
#  729: u'artificial',
#  730: u'asap',
#  731: u'asason',
#  732: u'ascend',
#  733: u'asia',
#  734: u'aside',
#  735: u'asign',
#  736: u'asin',
#  737: u'ask',
#  738: u'asked',
#  739: u'asking',
#  740: u'asks',
#  741: u'aslo',
#  742: u'aspect',
#  743: u'aspects',
#  744: u'aspirations',
#  745: u'ass',
#  746: u'assembling',
#  747: u'assembly',
#  748: u'assessment',
#  749: u'assessory',
#  750: u'asset',
#  751: u'assign',
#  752: u'assigned',
#  753: u'assignments',
#  754: u'assist',
#  755: u'assistance',
#  756: u'assortment',
#  757: u'assume',
#  758: u'assumed',
#  759: u'assumes',
#  760: u'assurance',
#  761: u'assure',
#  762: u'assured',
#  763: u'asus',
#  764: u'ate',
#  765: u'atlanta',
#  766: u'atleast',
#  767: u'atmosphere',
#  768: u'atmospheres',
#  769: u'atrocious',
#  770: u'att',
#  771: u'attach',
#  772: u'attachable',
#  773: u'attached',
#  774: u'attaches',
#  775: u'attachment',
#  776: u'attachments',
#  777: u'attacked',
#  778: u'attempt',
#  779: u'attempted',
#  780: u'attempting',
#  781: u'attempts',
#  782: u'attended',
#  783: u'attention',
#  784: u'attic',
#  785: u'attitude',
#  786: u'attract',
#  787: u'attracted',
#  788: u'attractive',
#  789: u'attracts',
#  790: u'attribute',
#  791: u'audible',
#  792: u'audibly',
#  793: u'audio',
#  794: u'audiophile',
#  795: u'audiovox',
#  796: u'aug',
#  797: u'augmented',
#  798: u'august',
#  799: u'australia',
#  800: u'authentic',
#  801: u'authetic',
#  802: u'authorities',
#  803: u'authorized',
#  804: u'auto',
#  805: u'autofocus',
#  806: u'automated',
#  807: u'automatic',
#  808: u'automatically',
#  809: u'automobile',
#  810: u'aux',
#  811: u'avail',
#  812: u'availability',
#  813: u'available',
#  814: u'availablility',
#  815: u'average',
#  816: u'avoid',
#  817: u'avoided',
#  818: u'avoiding',
#  819: u'awaay',
#  820: u'awaited',
#  821: u'awaiting',
#  822: u'aware',
#  823: u'away',
#  824: u'awayson',
#  825: u'awe',
#  826: u'aweful',
#  827: u'awesome',
#  828: u'awful',
#  829: u'awfully',
#  830: u'awhile',
#  831: u'awkardly',
#  832: u'awkward',
#  833: u'aworkable',
#  834: u'awsome',
#  835: u'ax',
#  836: u'axim',
#  837: u'axiously',
#  838: u'b0000cepc8',
#  839: u'b0009h7qkq',
#  840: u'ba',
#  841: u'baack',
#  842: u'babied',
#  843: u'babies',
#  844: u'baby',
#  845: u'babysat',
#  846: u'babyview20',
#  847: u'bacause',
#  848: u'backaround',
#  849: u'backberry',
#  850: u'backed',
#  851: u'background',
#  852: u'backing',
#  853: u'backlight',
#  854: u'backlighting',
#  855: u'backlit',
#  856: u'backround',
#  857: u'backside',
#  858: u'backup',
#  859: u'backups',
#  860: u'backward',
#  861: u'backwards',
#  862: u'bad',
#  863: u'badly',
#  864: u'bag',
#  865: u'bags',
#  866: u'bait',
#  867: u'balance',
#  868: u'balky',
#  869: u'ballpoint',
#  870: u'balls',
#  871: u'bam',
#  872: u'band',
#  873: u'bang',
#  874: u'bank',
#  875: u'banned',
#  876: u'bar',
#  877: u'bare',
#  878: u'barely',
#  879: u'bargain',
#  880: u'bargaincel',
#  881: u'bargaincell',
#  882: u'bargin',
#  883: u'barley',
#  884: u'barrier',
#  885: u'barrons',
#  886: u'bars',
#  887: u'barsof',
#  888: u'base',
#  889: u'based',
#  890: u'basement',
#  891: u'bash',
#  892: u'bashing',
#  893: u'basic',
#  894: u'basically',
#  895: u'basics',
#  896: u'basing',
#  897: u'basis',
#  898: u'bass',
#  899: u'bastante',
#  900: u'bat',
#  901: u'batch',
#  902: u'bathing',
#  903: u'battary',
#  904: u'batter',
#  905: u'batteries',
#  906: u'batterly',
#  907: u'battery',
#  908: u'batterymotorola',
#  909: u'battey',
#  910: u'batteyr',
#  911: u'battiers',
#  912: u'bay',
#  913: u'bb',
#  914: u'bbb',
#  915: u'beach',
#  916: u'beacuse',
#  917: u'beam',
#  918: u'bearable',
#  919: u'beat',
#  920: u'beaten',
#  921: u'beating',
#  922: u'beats',
#  923: u'beautiful',
#  924: u'beautifully',
#  925: u'beauty',
#  926: u'bec',
#  927: u'becuase',
#  928: u'bed',
#  929: u'beded',
#  930: u'bedroom',
#  931: u'bedrooms',
#  932: u'bedside',
#  933: u'beef',
#  934: u'beefs',
#  935: u'beenthe',
#  936: u'beep',
#  937: u'beeping',
#  938: u'beeps',
#  939: u'began',
#  940: u'begin',
#  941: u'beginers',
#  942: u'begining',
#  943: u'beginning',
#  944: u'begins',
#  945: u'behavior',
#  946: u'behing',
#  947: u'beings',
#  948: u'bejeweled',
#  949: u'beleve',
#  950: u'belief',
#  951: u'believe',
#  952: u'believed',
#  953: u'belive',
#  954: u'belkin',
#  955: u'bell',
#  956: u'bells',
#  957: u'belly',
#  958: u'belt',
#  959: u'beltclip',
#  960: u'belting',
#  961: u'belts',
#  962: u'bench',
#  963: u'bend',
#  964: u'bendable',
#  965: u'bending',
#  966: u'bends',
#  967: u'benefit',
#  968: u'benefits',
#  969: u'bent',
#  970: u'berry',
#  971: u'bes',
#  972: u'best',
#  973: u'bestbuy',
#  974: u'bet',
#  975: u'betrayed',
#  976: u'better',
#  977: u'bevy',
#  978: u'beware',
#  979: u'bezel',
#  980: u'bh',
#  981: u'bible',
#  982: u'bicycling',
#  983: u'bid',
#  984: u'big',
#  985: u'bigger',
#  986: u'biggest',
#  987: u'biggie',
#  988: u'bigtime',
#  989: u'bike',
#  990: u'biking',
#  991: u'billed',
#  992: u'billing',
#  993: u'bills',
#  994: u'binaural',
#  995: u'bind',
#  996: u'binds',
#  997: u'bird',
#  998: u'birthday',
#  999: u'birthdays',
#  ...}

# %% [markdown]
# ### We want to learn which columns are correlated (i.e., likely to come from the same topic).  This is the word distribution.  We can also determine what topics are in each document, the topic distribution.

# %%
# First we convert our word-matrix into gensim's format

corpus = matutils.Sparse2Corpus(documents, documents_columns = False)

# %% [markdown]
# (Check https://radimrehurek.com/gensim/matutils as needed)

# %%
corpus

# %% [markdown]
# (Check https://radimrehurek.com/gensim/models/ldamodel as needed)

# %%
# Then we fit an LDA model

model = models.ldamodel.LdaModel(corpus = corpus, num_topics = 25, id2word = id2word, passes = 10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c887fad368b7> in <module>()
#       1 # Then we fit an LDA model
#       2
# ----> 3 model = models.ldamodel.LdaModel(corpus = corpus, num_topics = 25, id2word = id2word, passes = 10)
#
# /Users/Aerlinger/.pyenv/versions/2.7.11/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability)
#     328         if corpus is not None:
#     329             use_numpy = self.dispatcher is not None
# --> 330             self.update(corpus, chunks_as_numpy=use_numpy)
#     331
#     332     def init_dir_prior(self, prior, name):
#
# /Users/Aerlinger/.pyenv/versions/2.7.11/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#     643                     logger.info('PROGRESS: pass %i, at document #%i/%i',
#     644                                 pass_, chunk_no * chunksize + len(chunk), lencorpus)
# --> 645                     gammat = self.do_estep(chunk, other)
#     646
#     647                     if self.optimize_alpha:
#
# /Users/Aerlinger/.pyenv/versions/2.7.11/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in do_estep(self, chunk, state)
#     479         if state is None:
#     480             state = self.state
# --> 481         gamma, sstats = self.inference(chunk, collect_sstats=True)
#     482         state.sstats += sstats
#     483         state.numdocs += gamma.shape[0]  # avoids calling len(chunk) on a generator
#
# /Users/Aerlinger/.pyenv/versions/2.7.11/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in inference(self, chunk, collect_sstats)
#     445                 # the update for gamma gives this update. Cf. Lee&Seung 2001.
#     446                 gammad = self.alpha + expElogthetad * numpy.dot(cts / phinorm, expElogbetad.T)
# --> 447                 Elogthetad = dirichlet_expectation(gammad)
#     448                 expElogthetad = numpy.exp(Elogthetad)
#     449                 phinorm = numpy.dot(expElogthetad, expElogbetad) + 1e-100
#
# /Users/Aerlinger/.pyenv/versions/2.7.11/lib/python2.7/site-packages/gensim/models/ldamodel.pyc in dirichlet_expectation(alpha)
#      63     """
#      64     if (len(alpha.shape) == 1):
# ---> 65         result = psi(alpha) - psi(numpy.sum(alpha))
#      66     else:
#      67         result = psi(alpha) - psi(numpy.sum(alpha, 1))[:, numpy.newaxis]
#
# KeyboardInterrupt:

# %% [markdown]
# In this model, we need to explicitly specify the number of topic we want the model to uncover.  This is a critical parameter, but there isn't much guidance on how to choose it.  Try to use domain expertise where possible.

# %%
model

# %% [markdown]
# ### Goodness of fit

# %% [markdown]
# Now we need to assess the goodness of fit for our model.  Like other unsupervised learning techniques, our validation techniques are mostly about interpretation.
#
# Use the following questions to guide you:
# - Did we learn reasonable topics?
# - Do the words that make up a topic make sense?
# - Is this topic helpful towards our goal?

# %%
model.print_topics()

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-458d5f1afc81> in <module>()
# ----> 1 model
#
# NameError: name 'model' is not defined

# %% [markdown]
# Some topics will be clearer than others.  The following topics represent clear concepts:
# - Cooking and Recipes: 0.009 \* cup + 0.009 \* recipe + 0.007 \* make + 0.007 \* food + 0.006 \* sugar
# - Cooking and recipes: 0.013 \* butter + 0.010 \* baking + 0.010 \* dough + 0.009 \* cup + 0.009 \* sugar
# - Fashion and Style: 0.013 \* fashion + 0.006 \* like + 0.006 \* dress + 0.005 \* style

# %% [markdown]
# ## Word2Vec with `gensim`

# %%
# Setup the body text
sentences = df.review.map(lambda review: review.split())

# %%
sentences
# Out:
# 0        [i, try, not, to, adjust, the, volume, setting...
# 1        [so, there, is, no, way, for, me, to, plug, it...
# 2                         [good, case,, excellent, value.]
# 3        [i, thought, motorola, made, reliable, product...
# 4                          [battery, for, motorola, razr.]
#                                ...
# 14999    [the, screen, on, my, phone, said, "not, charg...
# 15000    [this, is, my, 4th, samsung, cell, phone, with...
# 15001                                    [great, company.]
# 15002    [the, "call", and, "hang-up", keys, are, now, ...
# 15003         [hopefully, the, kyocera, will, be, better!]
# Name: review, dtype: object

# %%
model = models.Word2Vec(sentences, size = 100, window = 5, min_count = 5, workers = 4)

# %% [markdown]
# `Word2Vec` has many arguments:
# - `size` represents how many concepts or topics we should use
# - `window` represents how many words surrounding a sentence we should use as our original feature
# - `min_count` is the number of times that context or word must appear
# - `workers` is the number of CPU cores to use to speed up model training
#
# (Check http://radimrehurek.com/gensim/models/word2vec as needed)

# %%
model

# %% [markdown]
# ### Most similar words

# %% [markdown]
# The model has a `most_similar` function that helps find the words most similar to the one you queried.  This will return words that are most often used in the same context.

# %%
model.most_similar(positive = ['great'])
# Out:
# [('very', 0.9955066442489624),
#  ('good', 0.9861261248588562),
#  ('works', 0.9809689521789551),
#  ('battery', 0.9781995415687561),
#  ('as', 0.9767298698425293),
#  ('great.', 0.9744351506233215),
#  ('awful.', 0.9738140106201172),
#  ('sturdy.', 0.9736456274986267),
#  ('poor.', 0.9732855558395386),
#  ('is', 0.9721172451972961)]

# %%
vectorizer.get_feature_names()
# Out:
# [u'00',
#  u'000',
#  u'00332',
#  u'00pm',
#  u'01',
#  u'02',
#  u'04',
#  u'05',
#  u'06',
#  u'07',
#  u'08',
#  u'09',
#  u'093744',
#  u'10',
#  u'100',
#  u'1000',
#  u'1000mah',
#  u'100k',
#  u'100m',
#  u'102',
#  u'105',
#  u'109',
#  u'10meters',
#  u'10x',
#  u'11',
#  u'110',
#  u'1100',
#  u'1100mah',
#  u'112',
#  u'112kbps',
#  u'115',
#  u'118',
#  u'11mb',
#  u'11w',
#  u'12',
#  u'120',
#  u'121',
#  u'128',
#  u'128k',
#  u'128mb',
#  u'12v',
#  u'13',
#  u'1300',
#  u'1301',
#  u'14',
#  u'15',
#  u'150',
#  u'15g',
#  u'15th',
#  u'16',
#  u'1650sq',
#  u'16th',
#  u'17',
#  u'172x220',
#  u'175',
#  u'18',
#  u'1800',
#  u'1800beholy',
#  u'1800mah',
#  u'181',
#  u'19',
#  u'1900',
#  u'19005',
#  u'1945',
#  u'1955',
#  u'1999',
#  u'1gb',
#  u'1st',
#  u'1x',
#  u'20',
#  u'200',
#  u'2000',
#  u'2002',
#  u'2003',
#  u'2004',
#  u'2005',
#  u'2006',
#  u'2007',
#  u'2008',
#  u'2008update',
#  u'200mhz',
#  u'201',
#  u'2011',
#  u'2012when',
#  u'20912',
#  u'21',
#  u'2125',
#  u'215',
#  u'2160',
#  u'2169011',
#  u'22',
#  u'225',
#  u'2255',
#  u'22nd',
#  u'23',
#  u'24',
#  u'240',
#  u'2400mah',
#  u'2481',
#  u'25',
#  u'250',
#  u'250v',
#  u'25k',
#  u'25th',
#  u'26',
#  u'260',
#  u'269',
#  u'26th',
#  u'27',
#  u'270',
#  u'2700',
#  u'29',
#  u'29318ge1',
#  u'299',
#  u'2gb',
#  u'2mb',
#  u'2mp',
#  u'2nd',
#  u'2to3',
#  u'2x',
#  u'30',
#  u'300',
#  u'303',
#  u'3035',
#  u'305',
#  u'30mins',
#  u'30secs',
#  u'30usd',
#  u'31',
#  u'3125',
#  u'31st',
#  u'32',
#  u'320',
#  u'320k',
#  u'3220',
#  u'325',
#  u'32kbps',
#  u'33',
#  u'330',
#  u'335',
#  u'3360',
#  u'3390',
#  u'34',
#  u'340',
#  u'342',
#  u'35',
#  u'350',
#  u'3588i',
#  u'3595',
#  u'35mm',
#  u'36',
#  u'360',
#  u'3650',
#  u'375',
#  u'38718',
#  u'39',
#  u'3d',
#  u'3g',
#  u'3gp',
#  u'3gs',
#  u'3mpixel',
#  u'3o',
#  u'3r',
#  u'3rd',
#  u'3vm',
#  u'3x',
#  u'40',
#  u'400',
#  u'40ft',
#  u'411',
#  u'42',
#  u'44',
#  u'449',
#  u'45',
#  u'45mph',
#  u'47',
#  u'48',
#  u'480',
#  u'49',
#  u'4900',
#  u'4920',
#  u'4c',
#  u'4g',
#  u'4gb',
#  u'4gig',
#  u'4s',
#  u'4th',
#  u'4the',
#  u'4x',
#  u'50',
#  u'500',
#  u'5020',
#  u'509',
#  u'50x',
#  u'510',
#  u'510slplus',
#  u'512mb',
#  u'517',
#  u'520',
#  u'5300',
#  u'5320',
#  u'55',
#  u'550',
#  u'5500',
#  u'551',
#  u'55520',
#  u'5600',
#  u'5856',
#  u'59',
#  u'590a',
#  u'5bar',
#  u'5c',
#  u'5d',
#  u'5mm',
#  u'5mmi',
#  u'5mpixels',
#  u'5oz',
#  u'5rc',
#  u'5th',
#  u'60',
#  u'600',
#  u'600mah',
#  u'6010',
#  u'6030',
#  u'6061',
#  u'6080',
#  u'60gb',
#  u'61',
#  u'610',
#  u'6100',
#  u'6101',
#  u'6102',
#  u'6103',
#  u'6131',
#  u'616',
#  u'6160',
#  u'6165i',
#  u'6200',
#  u'6205',
#  u'6210',
#  u'6225',
#  u'6230',
#  u'6233',
#  u'6310i',
#  u'6315',
#  u'64',
#  u'640',
#  u'645',
#  u'64k',
#  u'64mb',
#  u'65',
#  u'650',
#  u'6515',
#  u'655',
#  u'6555',
#  u'6600',
#  u'665',
#  u'6650',
#  u'6700',
#  u'680',
#  u'6800',
#  u'690',
#  u'6c',
#  u'70',
#  u'700',
#  u'700p',
#  u'700w',
#  u'700wx',
#  u'700wxphone',
#  u'7050',
#  u'70mb',
#  u'71',
#  u'7100',
#  u'7100t',
#  u'72',
#  u'720',
#  u'720i',
#  u'720mah',
#  u'7250',
#  u'7300',
#  u'75',
#  u'750',
#  u'755p',
#  u'7575',
#  u'79',
#  u'7962',
#  u'7inch',
#  u'7th',
#  u'7v',
#  u'7xx',
#  u'80',
#  u'800',
#  u'800i',
#  u'8100',
#  u'810i',
#  u'8125',
#  u'8130',
#  u'820',
#  u'8200',
#  u'8260',
#  u'8290',
#  u'83',
#  u'8300',
#  u'8320',
#  u'8330',
#  u'850',
#  u'8525',
#  u'8530',
#  u'8550',
#  u'86',
#  u'8610',
#  u'8700',
#  u'8700c',
#  u'8700g',
#  u'8703',
#  u'88',
#  u'880',
#  u'8800',
#  u'8801',
#  u'887',
#  u'89',
#  u'8920',
#  u'8940',
#  u'8gb',
#  u'8mb',
#  u'8th',
#  u'90',
#  u'900',
#  u'910',
#  u'9100',
#  u'910a',
#  u'911',
#  u'92',
#  u'920',
#  u'925',
#  u'95',
#  u'950',
#  u'96',
#  u'97',
#  u'975',
#  u'98shippingnew',
#  u'99',
#  u'9month',
#  u'9q',
#  u'a1',
#  u'a1200',
#  u'a120s',
#  u'a125s',
#  u'a210',
#  u'a2dp',
#  u'a43',
#  u'a460',
#  u'a500',
#  u'a640',
#  u'a670',
#  u'a680',
#  u'a707',
#  u'a767',
#  u'a900',
#  u'a920',
#  u'a940',
#  u'a950',
#  u'a990',
#  u'aa',
#  u'aaa',
#  u'aac',
#  u'aacute',
#  u'aain',
#  u'abdate',
#  u'aberration',
#  u'abhor',
#  u'abilities',
#  u'ability',
#  u'able',
#  u'abound',
#  u'abscence',
#  u'absolute',
#  u'absolutel',
#  u'absolutely',
#  u'absurd',
#  u'abuse',
#  u'abysmal',
#  u'ac',
#  u'accent',
#  u'accept',
#  u'acceptable',
#  u'accepting',
#  u'access',
#  u'accessable',
#  u'accesses',
#  u'accessible',
#  u'accessing',
#  u'accessories',
#  u'accessory',
#  u'accessoryone',
#  u'accessoryonecondition',
#  u'accident',
#  u'accidental',
#  u'accidentally',
#  u'accidently',
#  u'accommodate',
#  u'accommodating',
#  u'accomodating',
#  u'accompanied',
#  u'accomplish',
#  u'accomplished',
#  u'accord',
#  u'according',
#  u'account',
#  u'accounts',
#  u'acct',
#  u'accumulates',
#  u'accurate',
#  u'accurately',
#  u'accustomed',
#  u'ace',
#  u'acess',
#  u'acessing',
#  u'acessories',
#  u'achieve',
#  u'achieving',
#  u'acoustibuds',
#  u'acquired',
#  u'acrylic',
#  u'act',
#  u'acting',
#  u'action',
#  u'activate',
#  u'activated',
#  u'activates',
#  u'activatethrice',
#  u'activating',
#  u'activation',
#  u'active',
#  u'activesync',
#  u'activity',
#  u'acts',
#  u'actual',
#  u'actually',
#  u'acutally',
#  u'ad',
#  u'adapt',
#  u'adaptable',
#  u'adapter',
#  u'adapters',
#  u'adaptor',
#  u'adaptors',
#  u'adaquate',
#  u'adavertised',
#  u'add',
#  u'added',
#  u'adding',
#  u'addition',
#  u'additional',
#  u'additionally',
#  u'address',
#  u'addressed',
#  u'addresses',
#  u'adds',
#  u'addvertised',
#  u'adequate',
#  u'adequately',
#  u'adhesive',
#  u'aditional',
#  u'adjacent',
#  u'adjust',
#  u'adjustable',
#  u'adjusted',
#  u'adjusting',
#  u'adjustment',
#  u'adjustments',
#  u'adjusts',
#  u'administrator',
#  u'admit',
#  u'admitted',
#  u'adobe',
#  u'adorable',
#  u'adore',
#  u'adpater',
#  u'ads',
#  u'adt',
#  u'adult',
#  u'adustable',
#  u'advance',
#  u'advanced',
#  u'advantage',
#  u'adverstised',
#  u'advertise',
#  u'advertised',
#  u'advertisement',
#  u'advertisements',
#  u'advertising',
#  u'advertisment',
#  u'advetisement',
#  u'advice',
#  u'advise',
#  u'advises',
#  u'aesthetically',
#  u'aesthetics',
#  u'afer',
#  u'affected',
#  u'afford',
#  u'affordable',
#  u'affords',
#  u'afraid',
#  u'africa',
#  u'afterall',
#  u'aftermarket',
#  u'afterthought',
#  u'aftertrying',
#  u'afterward',
#  u'againultra',
#  u'age',
#  u'aged',
#  u'agey',
#  u'aggie',
#  u'aggravating',
#  u'aggravation',
#  u'agian',
#  u'ago',
#  u'agonizing',
#  u'agravated',
#  u'agravation',
#  u'agree',
#  u'agreed',
#  u'agreement',
#  u'ah',
#  u'ahead',
#  u'ahhhs',
#  u'ahora',
#  u'ahve',
#  u'aid',
#  u'aim',
#  u'ain',
#  u'air',
#  u'airplane',
#  u'airplanes',
#  u'airport',
#  u'airports',
#  u'airtime',
#  u'airwaves',
#  u'airy',
#  u'ajstudio',
#  u'aka',
#  u'al',
#  u'alabama',
#  u'alarm',
#  u'alarms',
#  u'alaska',
#  u'albeit',
#  u'album',
#  u'alcohol',
#  u'alert',
#  u'ali',
#  u'alias',
#  u'aligned',
#  u'alignment',
#  u'alike',
#  u'aliph',
#  u'alittle',
#  u'alive',
#  u'alleviate',
#  u'allot',
#  u'alloted',
#  u'allotted',
#  u'allow',
#  u'allowed',
#  u'allowing',
#  u'allows',
#  u'allright',
#  u'alltel',
#  u'alltogether',
#  u'alot',
#  u'alow',
#  u'alpha',
#  u'alright',
#  u'alteration',
#  u'alternate',
#  u'alternately',
#  u'alternative',
#  u'alternatives',
#  u'altho',
#  u'althought',
#  u'altogether',
#  u'aluminum',
#  u'amaizing',
#  u'amaozons',
#  u'amaze',
#  u'amazed',
#  u'amazing',
#  u'amazingly',
#  u'amazingy',
#  u'amazon',
#  u'amazons',
#  u'amber',
#  u'ambient',
#  u'amenities',
#  u'america',
#  u'american',
#  u'amfm',
#  u'amigo',
#  u'amoled',
#  u'amounts',
#  u'amp',
#  u'ample',
#  u'ampleflier',
#  u'amplification',
#  u'amplified',
#  u'amplifier',
#  u'amplifies',
#  u'amps',
#  u'analog',
#  u'anatomy',
#  u'anchor',
#  u'andf',
#  u'andn',
#  u'android',
#  u'andy',
#  u'anf',
#  u'angeles',
#  u'angle',
#  u'angles',
#  u'angry',
#  u'angst',
#  u'anil',
#  u'animal',
#  u'animated',
#  u'animations',
#  u'announcemenet',
#  u'announcements',
#  u'annoyance',
#  u'annoyances',
#  u'annoyed',
#  u'annoying',
#  u'annoyingly',
#  u'anoying',
#  u'answer',
#  u'answered',
#  u'answering',
#  u'answers',
#  u'ant',
#  u'antena',
#  u'antenna',
#  u'antennae',
#  u'anti',
#  u'anticipated',
#  u'antique',
#  u'antonio',
#  u'antonline',
#  u'antronics',
#  u'anybody',
#  u'anymore',
#  u'anytime',
#  u'anyting',
#  u'anyways',
#  u'aout',
#  u'aparce',
#  u'apart',
#  u'apartment',
#  u'aperture',
#  u'apiece',
#  u'apologize',
#  u'apologized',
#  u'apologizes',
#  u'apology',
#  u'appalled',
#  u'apparent',
#  u'apparently',
#  u'appeal',
#  u'appealing',
#  u'appeals',
#  u'appear',
#  u'appearance',
#  u'appeared',
#  u'appearence',
#  u'appears',
#  u'appereance',
#  u'apple',
#  u'application',
#  u'applications',
#  u'applied',
#  u'applies',
#  u'applifies',
#  u'apply',
#  u'applying',
#  u'appointment',
#  u'appointments',
#  u'appologized',
#  u'appose',
#  u'appreciate',
#  u'appreciated',
#  u'apprehensive',
#  u'approach',
#  u'appropriate',
#  u'approved',
#  u'approx',
#  u'approximately',
#  u'apps',
#  u'april',
#  u'apt',
#  u'aquos',
#  u'arch',
#  u'area',
#  u'areas',
#  u'aren',
#  u'arent',
#  u'ares',
#  u'arggggggggg',
#  u'argued',
#  u'arguing',
#  u'arm',
#  u'armband',
#  u'armies',
#  u'armor',
#  u'arose',
#  u'arrangement',
#  u'arrangements',
#  u'arrests',
#  u'arrival',
#  u'arrive',
#  u'arrived',
#  u'arrives',
#  u'arrow',
#  u'arrows',
#  u'art',
#  u'article',
#  u'articles',
#  u'articulo',
#  u'artifact',
#  u'artificial',
#  u'asap',
#  u'asason',
#  u'ascend',
#  u'asia',
#  u'aside',
#  u'asign',
#  u'asin',
#  u'ask',
#  u'asked',
#  u'asking',
#  u'asks',
#  u'aslo',
#  u'aspect',
#  u'aspects',
#  u'aspirations',
#  u'ass',
#  u'assembling',
#  u'assembly',
#  u'assessment',
#  u'assessory',
#  u'asset',
#  u'assign',
#  u'assigned',
#  u'assignments',
#  u'assist',
#  u'assistance',
#  u'assortment',
#  u'assume',
#  u'assumed',
#  u'assumes',
#  u'assurance',
#  u'assure',
#  u'assured',
#  u'asus',
#  u'ate',
#  u'atlanta',
#  u'atleast',
#  u'atmosphere',
#  u'atmospheres',
#  u'atrocious',
#  u'att',
#  u'attach',
#  u'attachable',
#  u'attached',
#  u'attaches',
#  u'attachment',
#  u'attachments',
#  u'attacked',
#  u'attempt',
#  u'attempted',
#  u'attempting',
#  u'attempts',
#  u'attended',
#  u'attention',
#  u'attic',
#  u'attitude',
#  u'attract',
#  u'attracted',
#  u'attractive',
#  u'attracts',
#  u'attribute',
#  u'audible',
#  u'audibly',
#  u'audio',
#  u'audiophile',
#  u'audiovox',
#  u'aug',
#  u'augmented',
#  u'august',
#  u'australia',
#  u'authentic',
#  u'authetic',
#  u'authorities',
#  u'authorized',
#  u'auto',
#  u'autofocus',
#  u'automated',
#  u'automatic',
#  u'automatically',
#  u'automobile',
#  u'aux',
#  u'avail',
#  u'availability',
#  u'available',
#  u'availablility',
#  u'average',
#  u'avoid',
#  u'avoided',
#  u'avoiding',
#  u'awaay',
#  u'awaited',
#  u'awaiting',
#  u'aware',
#  u'away',
#  u'awayson',
#  u'awe',
#  u'aweful',
#  u'awesome',
#  u'awful',
#  u'awfully',
#  u'awhile',
#  u'awkardly',
#  u'awkward',
#  u'aworkable',
#  u'awsome',
#  u'ax',
#  u'axim',
#  u'axiously',
#  u'b0000cepc8',
#  u'b0009h7qkq',
#  u'ba',
#  u'baack',
#  u'babied',
#  u'babies',
#  u'baby',
#  u'babysat',
#  u'babyview20',
#  u'bacause',
#  u'backaround',
#  u'backberry',
#  u'backed',
#  u'background',
#  u'backing',
#  u'backlight',
#  u'backlighting',
#  u'backlit',
#  u'backround',
#  u'backside',
#  u'backup',
#  u'backups',
#  u'backward',
#  u'backwards',
#  u'bad',
#  u'badly',
#  u'bag',
#  u'bags',
#  u'bait',
#  u'balance',
#  u'balky',
#  u'ballpoint',
#  u'balls',
#  u'bam',
#  u'band',
#  u'bang',
#  u'bank',
#  u'banned',
#  u'bar',
#  u'bare',
#  u'barely',
#  u'bargain',
#  u'bargaincel',
#  u'bargaincell',
#  u'bargin',
#  u'barley',
#  u'barrier',
#  u'barrons',
#  u'bars',
#  u'barsof',
#  u'base',
#  u'based',
#  u'basement',
#  u'bash',
#  u'bashing',
#  u'basic',
#  u'basically',
#  u'basics',
#  u'basing',
#  u'basis',
#  u'bass',
#  u'bastante',
#  u'bat',
#  u'batch',
#  u'bathing',
#  u'battary',
#  u'batter',
#  u'batteries',
#  u'batterly',
#  u'battery',
#  u'batterymotorola',
#  u'battey',
#  u'batteyr',
#  u'battiers',
#  u'bay',
#  u'bb',
#  u'bbb',
#  u'beach',
#  u'beacuse',
#  u'beam',
#  u'bearable',
#  u'beat',
#  u'beaten',
#  u'beating',
#  u'beats',
#  u'beautiful',
#  u'beautifully',
#  u'beauty',
#  u'bec',
#  u'becuase',
#  u'bed',
#  u'beded',
#  u'bedroom',
#  u'bedrooms',
#  u'bedside',
#  u'beef',
#  u'beefs',
#  u'beenthe',
#  u'beep',
#  u'beeping',
#  u'beeps',
#  u'began',
#  u'begin',
#  u'beginers',
#  u'begining',
#  u'beginning',
#  u'begins',
#  u'behavior',
#  u'behing',
#  u'beings',
#  u'bejeweled',
#  u'beleve',
#  u'belief',
#  u'believe',
#  u'believed',
#  u'belive',
#  u'belkin',
#  u'bell',
#  u'bells',
#  u'belly',
#  u'belt',
#  u'beltclip',
#  u'belting',
#  u'belts',
#  u'bench',
#  u'bend',
#  u'bendable',
#  u'bending',
#  u'bends',
#  u'benefit',
#  u'benefits',
#  u'bent',
#  u'berry',
#  u'bes',
#  u'best',
#  u'bestbuy',
#  u'bet',
#  u'betrayed',
#  u'better',
#  u'bevy',
#  u'beware',
#  u'bezel',
#  u'bh',
#  u'bible',
#  u'bicycling',
#  u'bid',
#  u'big',
#  u'bigger',
#  u'biggest',
#  u'biggie',
#  u'bigtime',
#  u'bike',
#  u'biking',
#  u'billed',
#  u'billing',
#  u'bills',
#  u'binaural',
#  u'bind',
#  u'binds',
#  u'bird',
#  u'birthday',
#  u'birthdays',
#  ...]

# %%
sentences
# Out:
# 0        [i, try, not, to, adjust, the, volume, setting...
# 1        [so, there, is, no, way, for, me, to, plug, it...
# 2                         [good, case,, excellent, value.]
# 3        [i, thought, motorola, made, reliable, product...
# 4                          [battery, for, motorola, razr.]
#                                ...
# 14999    [the, screen, on, my, phone, said, "not, charg...
# 15000    [this, is, my, 4th, samsung, cell, phone, with...
# 15001                                    [great, company.]
# 15002    [the, "call", and, "hang-up", keys, are, now, ...
# 15003         [hopefully, the, kyocera, will, be, better!]
# Name: review, dtype: object

# %%
sentences = list(map(lambda sentence: list(filter(lambda word: word in vectorizer.get_feature_names(), sentence)), sentences))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-3b696919d169> in <module>()
# ----> 1 sentences = list(map(lambda sentence: list(filter(lambda word: word in vectorizer.get_feature_names(), sentence)), sentences))
#
# <ipython-input-27-3b696919d169> in <lambda>(sentence)
# ----> 1 sentences = list(map(lambda sentence: list(filter(lambda word: word in vectorizer.get_feature_names(), sentence)), sentences))
#
# <ipython-input-27-3b696919d169> in <lambda>(word)
# ----> 1 sentences = list(map(lambda sentence: list(filter(lambda word: word in vectorizer.get_feature_names(), sentence)), sentences))
#
# /Users/Aerlinger/.pyenv/versions/2.7.11/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in get_feature_names(self)
#     904
#     905         return [t for t, i in sorted(six.iteritems(self.vocabulary_),
# --> 906                                      key=itemgetter(1))]
#     907
#     908
#
# KeyboardInterrupt:

# %%
sentences

# %%
model = models.Word2Vec(sentences, size = 100, window = 5, min_count = 5, workers = 4)

# %%
model.most_similar(positive = ['great'])
