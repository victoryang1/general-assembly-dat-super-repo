# %% [markdown]
# # Pandas Part 2 & Plotting

# %% [markdown]
# ## Agenda
# <br>
#
#     - Concatenating and merging pandas dataframes
#     - Introduction to making graphs/charts using Matplotlib and Pandas: Scatter, line, bar, boxplots, etc..
#     - Classwork exercises on plotting.

# %% [markdown]
# ### Concatenating Dataframes
#
# Concatenating is a complex way of saying you want to attach together two different objects, in case pandas data frame. In this part we'll be attaching dataframes top to bottom and side by side.

# %%
#Imports
import numpy as np
import pandas as pd

# %%
#Use numpy to create some data.
array1 = np.random.normal(loc = 5, size = (100, 3))
array2 = np.random.normal(loc = -5, size = (100, 3))

#Creat column names
cols = ["feature_1", "feature_2", "feature_3"]

#Feed arrays and cols into dataframes
df1 = pd.DataFrame(array1, columns=cols)
df2 = pd.DataFrame(array2, columns=cols)

# %%
#View df1
df1.head()
# Out:
#    feature_1  feature_2  feature_3
# 0   3.716087   5.171302   3.602006
# 1   5.301098   5.837307   3.911467
# 2   4.923365   3.379430   3.563333
# 3   6.505084   5.849300   3.952908
# 4   5.546745   3.992765   4.027071

# %%
#View df2
df2.head()
# Out:
#    feature_1  feature_2  feature_3
# 0  -3.793969  -5.598227  -3.764277
# 1  -5.309839  -6.006855  -3.709596
# 2  -4.643318  -4.255489  -3.913249
# 3  -4.775398  -6.922798  -5.699495
# 4  -4.553980  -4.133185  -5.701259

# %% [markdown]
# We have two 100 x 3 dataframes and now we're going to concatenate along axis 0. Remember axis = 0/1?

# %%
pd.set_option("max.rows", None)

# %%
#Call pandas concatenate method on df1 and df2

#The dataframes you want to concatenate must be organized into a list
list_of_dataframes = [df1, df2]
#Remeber axis = 0 is there, it's hidden but it's there.
data1 = pd.concat(list_of_dataframes)

#View concatenated dataframe which is 200 rows by 3 columns
data1
# Out:
#     feature_1  feature_2  feature_3
# 0    3.716087   5.171302   3.602006
# 1    5.301098   5.837307   3.911467
# 2    4.923365   3.379430   3.563333
# 3    6.505084   5.849300   3.952908
# 4    5.546745   3.992765   4.027071
# 5    5.412735   6.123299   6.477051
# 6    3.250100   4.336060   4.202233
# 7    5.830890   4.951054   5.265770
# 8    3.435068   5.219602   4.498841
# 9    6.819388   5.982144   7.207159
# 10   3.081499   7.458796   5.317856
# 11   3.984519   2.876433   6.779134
# 12   5.027042   2.475283   5.849726
# 13   4.660183   5.293472   6.820249
# 14   4.360895   5.147047   6.335625
# 15   3.254465   5.172313   4.408629
# 16   4.827781   4.387131   5.964306
# 17   5.172943   4.922949   5.435020
# 18   5.060618   5.503563   5.004594
# 19   5.846159   5.653654   5.747828
# 20   5.017748   5.605813   4.374113
# 21   3.636517   4.251847   4.851058
# 22   6.381144   5.033762   5.928963
# 23   5.098768   5.211676   4.238371
# 24   6.233399   4.667344   5.125960
# 25   3.869833   5.073354   6.769742
# 26   4.449180   5.792658   5.583837
# 27   5.489611   5.919561   5.016208
# 28   4.774673   5.510034   5.667677
# 29   6.069081   5.242882   6.086364
# 30   4.659464   3.521692   4.148205
# 31   2.579990   4.754013   3.244401
# 32   5.919983   6.045693   5.264080
# 33   3.262616   3.841616   5.072345
# 34   6.036278   4.076167   5.184975
# 35   4.670187   6.798740   6.106239
# 36   4.812951   5.976260   5.160185
# 37   5.577386   4.480574   3.925428
# 38   4.310908   6.126917   5.431132
# 39   6.569214   4.543141   4.277520
# 40   6.545449   5.354579   3.771202
# 41   4.682347   3.426253   4.941474
# 42   4.903099   6.503671   5.691353
# 43   4.509073   5.713108   5.967021
# 44   4.779208   3.626076   5.295906
# 45   5.512979   6.014207   4.674592
# 46   4.870148   3.141518   3.778578
# 47   4.585589   6.061052   5.428289
# 48   6.207001   4.580595   3.170969
# 49   7.801053   4.770113   5.672133
# 50   4.449270   5.931788   4.826297
# 51   5.060786   5.038555   4.277787
# 52   5.227708   3.398480   5.270493
# 53   5.774125   6.740061   5.183919
# 54   6.419882   5.293923   6.049838
# 55   4.591597   5.576045   4.014505
# 56   6.090527   4.465463   4.634919
# 57   4.977693   3.707122   5.636822
# 58   6.359051   6.316360   4.744510
# 59   5.053319   5.922739   3.340954
# 60   5.583789   4.582241   5.925459
# 61   4.765360   5.572549   5.973089
# 62   5.039861   6.577805   4.457692
# 63   4.697769   4.600304   4.316783
# 64   5.407654   6.149660   4.237420
# 65   4.105859   7.357035   3.824973
# 66   5.237117   6.746960   4.603443
# 67   4.949865   5.415263   4.058810
# 68   5.252836   6.820049   4.782567
# 69   5.616190   5.799121   5.124407
# 70   5.067872   4.984517   6.182709
# 71   4.226973   4.822580   5.692611
# 72   6.071524   3.481512   8.029383
# 73   7.391641   5.059103   3.787793
# 74   5.277824   4.272563   4.870127
# 75   4.186388   3.837097   5.414781
# 76   6.354408   4.824496   5.006216
# 77   5.153918   3.603332   6.880928
# 78   6.112424   5.333547   4.868795
# 79   5.389222   4.569140   5.981655
# 80   6.254856   3.422902   4.909223
# 81   3.511435   6.021757   4.398380
# 82   6.243028   4.416283   3.851591
# 83   3.972883   4.017579   5.616942
# 84   5.646885   3.793863   5.246928
# 85   5.303484   4.654340   5.199125
# 86   3.140579   4.054933   5.567626
# 87   5.090650   4.136561   4.604413
# 88   4.876373   5.944892   3.723252
# 89   6.153768   4.972901   3.088429
# 90   3.704383   6.052040   3.653583
# 91   4.148793   5.590005   4.646451
# 92   4.521143   6.273618   5.393506
# 93   5.888781   3.481825   5.398327
# 94   4.788273   2.034275   5.368705
# 95   5.728894   4.660829   5.072960
# 96   4.954718   4.733051   5.411436
# 97   3.104683   4.895616   6.238464
# 98   5.951366   5.769844   6.295771
# 99   5.972146   6.951955   5.630261
# 0   -3.793969  -5.598227  -3.764277
# 1   -5.309839  -6.006855  -3.709596
# 2   -4.643318  -4.255489  -3.913249
# 3   -4.775398  -6.922798  -5.699495
# 4   -4.553980  -4.133185  -5.701259
# 5   -4.892043  -3.812628  -3.375390
# 6   -4.391813  -6.384031  -6.908305
# 7   -4.130508  -4.156403  -5.327933
# 8   -3.884566  -4.366237  -5.375676
# 9   -4.817457  -3.612930  -5.936748
# 10  -6.132143  -4.100261  -5.534260
# 11  -7.465055  -4.631828  -4.669663
# 12  -6.187273  -5.972195  -4.566936
# 13  -6.072283  -4.889216  -4.836868
# 14  -6.575330  -6.902261  -5.692658
# 15  -3.627425  -5.551682  -3.985545
# 16  -5.610000  -5.141920  -6.408516
# 17  -5.097002  -5.285820  -4.078573
# 18  -5.294299  -4.768467  -3.247701
# 19  -4.253200  -3.999229  -5.458764
# 20  -4.029684  -6.027577  -5.485211
# 21  -4.090465  -6.614790  -6.984633
# 22  -5.567728  -4.871958  -3.439879
# 23  -6.062817  -5.168759  -5.822698
# 24  -4.702743  -4.471624  -5.158048
# 25  -5.251510  -6.383228  -5.490038
# 26  -7.311092  -3.945182  -6.498615
# 27  -6.732629  -4.536790  -5.135136
# 28  -4.440572  -4.096098  -4.779298
# 29  -5.616999  -4.457790  -3.291381
# 30  -4.502145  -6.649539  -2.884055
# 31  -6.063886  -5.011436  -6.179478
# 32  -2.817416  -3.453702  -3.985603
# 33  -4.554659  -5.383843  -5.821270
# 34  -4.668346  -5.310244  -4.846380
# 35  -4.791770  -4.844193  -5.274447
# 36  -4.595774  -5.242705  -5.318182
# 37  -5.284024  -4.967630  -4.187205
# 38  -4.841668  -5.609818  -3.766669
# 39  -4.073152  -4.935977  -5.891419
# 40  -5.492571  -3.837747  -5.456167
# 41  -4.334869  -3.785938  -3.597966
# 42  -5.416347  -5.047462  -5.327117
# 43  -5.071179  -5.798655  -5.528472
# 44  -6.508331  -5.125363  -5.764247
# 45  -5.952532  -5.986654  -5.484893
# 46  -5.042540  -5.954532  -3.605189
# 47  -2.682899  -4.874390  -5.761318
# 48  -5.166055  -4.117039  -4.773668
# 49  -4.135698  -5.386040  -3.679128
# 50  -2.644114  -3.948300  -4.935484
# 51  -6.542707  -4.269911  -4.800564
# 52  -5.218202  -4.013638  -5.902914
# 53  -3.829075  -6.155974  -6.114168
# 54  -5.681101  -6.956995  -3.337229
# 55  -4.445546  -5.723914  -4.827296
# 56  -5.649776  -4.209200  -4.474612
# 57  -3.655015  -4.496723  -5.565300
# 58  -5.748539  -4.400910  -5.097966
# 59  -4.604924  -5.464354  -6.530099
# 60  -3.122819  -5.088951  -4.637854
# 61  -6.079828  -6.033159  -3.934726
# 62  -5.175924  -4.680317  -4.661884
# 63  -4.646899  -4.840725  -4.927589
# 64  -5.021579  -5.805116  -3.496296
# 65  -4.228207  -5.384843  -5.973314
# 66  -5.152829  -6.854860  -5.279041
# 67  -3.624746  -5.810661  -3.138589
# 68  -6.351235  -5.978817  -6.011008
# 69  -3.620107  -5.512795  -4.851195
# 70  -5.336383  -4.516707  -5.703969
# 71  -5.389765  -5.044311  -5.452246
# 72  -6.055112  -6.055259  -6.255305
# 73  -3.041820  -3.802031  -5.810256
# 74  -6.598770  -3.143120  -5.025673
# 75  -3.737113  -4.523212  -5.958027
# 76  -5.072979  -4.839745  -5.381270
# 77  -4.620856  -4.184614  -7.263228
# 78  -6.072101  -2.834850  -5.840046
# 79  -4.511325  -4.385044  -4.899481
# 80  -5.531162  -4.940593  -5.836310
# 81  -4.530171  -5.557578  -4.557679
# 82  -4.820164  -4.287399  -4.791096
# 83  -2.668421  -6.213763  -4.816004
# 84  -5.084320  -4.332774  -4.966168
# 85  -5.239130  -3.713061  -4.473316
# 86  -4.626052  -4.703358  -5.028605
# 87  -4.015521  -4.311011  -5.446234
# 88  -4.511636  -5.980926  -5.383505
# 89  -4.570742  -4.649980  -4.879863
# 90  -4.324947  -5.448458  -3.983996
# 91  -5.875992  -4.575903  -4.777507
# 92  -4.888772  -2.225518  -3.293018
# 93  -3.368177  -4.665367  -5.400561
# 94  -5.255446  -6.075079  -5.295260
# 95  -5.960578  -4.951044  -3.975907
# 96  -5.809033  -6.193312  -5.479789
# 97  -5.866025  -5.486002  -4.344293
# 98  -5.354228  -4.778081  -6.423437
# 99  -4.953334  -5.277490  -4.634101

# %% [markdown]
# There is an issue here? What is it?

# %% [markdown]
# We have duplicate index values!

# %%
#We can reset the index
data1.reset_index(inplace=True)

# %% [markdown]
# Concatenate dataframes along axis 1 aka attach dataframes side by side.

# %%
#Change column names of df2 so we avoid duplication issue
col2 = ["feature_4", "feature_5", "feature_6"]

df2.columns = col2
df2.head(3)
# Out:
#    feature_4  feature_5  feature_6
# 0  -3.793969  -5.598227  -3.764277
# 1  -5.309839  -6.006855  -3.709596
# 2  -4.643318  -4.255489  -3.913249

# %%
#Make list of dataframes
dflist = [df1, df2]

#Concatenate dataframes but this time set axis = 1
data2 = pd.concat(dflist, axis=1)

#View concatenated dataframe which 100 rows by 4 columns

data2
# Out:
#     feature_1  feature_2  feature_3  feature_4  feature_5  feature_6
# 0    3.716087   5.171302   3.602006  -3.793969  -5.598227  -3.764277
# 1    5.301098   5.837307   3.911467  -5.309839  -6.006855  -3.709596
# 2    4.923365   3.379430   3.563333  -4.643318  -4.255489  -3.913249
# 3    6.505084   5.849300   3.952908  -4.775398  -6.922798  -5.699495
# 4    5.546745   3.992765   4.027071  -4.553980  -4.133185  -5.701259
# 5    5.412735   6.123299   6.477051  -4.892043  -3.812628  -3.375390
# 6    3.250100   4.336060   4.202233  -4.391813  -6.384031  -6.908305
# 7    5.830890   4.951054   5.265770  -4.130508  -4.156403  -5.327933
# 8    3.435068   5.219602   4.498841  -3.884566  -4.366237  -5.375676
# 9    6.819388   5.982144   7.207159  -4.817457  -3.612930  -5.936748
# 10   3.081499   7.458796   5.317856  -6.132143  -4.100261  -5.534260
# 11   3.984519   2.876433   6.779134  -7.465055  -4.631828  -4.669663
# 12   5.027042   2.475283   5.849726  -6.187273  -5.972195  -4.566936
# 13   4.660183   5.293472   6.820249  -6.072283  -4.889216  -4.836868
# 14   4.360895   5.147047   6.335625  -6.575330  -6.902261  -5.692658
# 15   3.254465   5.172313   4.408629  -3.627425  -5.551682  -3.985545
# 16   4.827781   4.387131   5.964306  -5.610000  -5.141920  -6.408516
# 17   5.172943   4.922949   5.435020  -5.097002  -5.285820  -4.078573
# 18   5.060618   5.503563   5.004594  -5.294299  -4.768467  -3.247701
# 19   5.846159   5.653654   5.747828  -4.253200  -3.999229  -5.458764
# 20   5.017748   5.605813   4.374113  -4.029684  -6.027577  -5.485211
# 21   3.636517   4.251847   4.851058  -4.090465  -6.614790  -6.984633
# 22   6.381144   5.033762   5.928963  -5.567728  -4.871958  -3.439879
# 23   5.098768   5.211676   4.238371  -6.062817  -5.168759  -5.822698
# 24   6.233399   4.667344   5.125960  -4.702743  -4.471624  -5.158048
# 25   3.869833   5.073354   6.769742  -5.251510  -6.383228  -5.490038
# 26   4.449180   5.792658   5.583837  -7.311092  -3.945182  -6.498615
# 27   5.489611   5.919561   5.016208  -6.732629  -4.536790  -5.135136
# 28   4.774673   5.510034   5.667677  -4.440572  -4.096098  -4.779298
# 29   6.069081   5.242882   6.086364  -5.616999  -4.457790  -3.291381
# 30   4.659464   3.521692   4.148205  -4.502145  -6.649539  -2.884055
# 31   2.579990   4.754013   3.244401  -6.063886  -5.011436  -6.179478
# 32   5.919983   6.045693   5.264080  -2.817416  -3.453702  -3.985603
# 33   3.262616   3.841616   5.072345  -4.554659  -5.383843  -5.821270
# 34   6.036278   4.076167   5.184975  -4.668346  -5.310244  -4.846380
# 35   4.670187   6.798740   6.106239  -4.791770  -4.844193  -5.274447
# 36   4.812951   5.976260   5.160185  -4.595774  -5.242705  -5.318182
# 37   5.577386   4.480574   3.925428  -5.284024  -4.967630  -4.187205
# 38   4.310908   6.126917   5.431132  -4.841668  -5.609818  -3.766669
# 39   6.569214   4.543141   4.277520  -4.073152  -4.935977  -5.891419
# 40   6.545449   5.354579   3.771202  -5.492571  -3.837747  -5.456167
# 41   4.682347   3.426253   4.941474  -4.334869  -3.785938  -3.597966
# 42   4.903099   6.503671   5.691353  -5.416347  -5.047462  -5.327117
# 43   4.509073   5.713108   5.967021  -5.071179  -5.798655  -5.528472
# 44   4.779208   3.626076   5.295906  -6.508331  -5.125363  -5.764247
# 45   5.512979   6.014207   4.674592  -5.952532  -5.986654  -5.484893
# 46   4.870148   3.141518   3.778578  -5.042540  -5.954532  -3.605189
# 47   4.585589   6.061052   5.428289  -2.682899  -4.874390  -5.761318
# 48   6.207001   4.580595   3.170969  -5.166055  -4.117039  -4.773668
# 49   7.801053   4.770113   5.672133  -4.135698  -5.386040  -3.679128
# 50   4.449270   5.931788   4.826297  -2.644114  -3.948300  -4.935484
# 51   5.060786   5.038555   4.277787  -6.542707  -4.269911  -4.800564
# 52   5.227708   3.398480   5.270493  -5.218202  -4.013638  -5.902914
# 53   5.774125   6.740061   5.183919  -3.829075  -6.155974  -6.114168
# 54   6.419882   5.293923   6.049838  -5.681101  -6.956995  -3.337229
# 55   4.591597   5.576045   4.014505  -4.445546  -5.723914  -4.827296
# 56   6.090527   4.465463   4.634919  -5.649776  -4.209200  -4.474612
# 57   4.977693   3.707122   5.636822  -3.655015  -4.496723  -5.565300
# 58   6.359051   6.316360   4.744510  -5.748539  -4.400910  -5.097966
# 59   5.053319   5.922739   3.340954  -4.604924  -5.464354  -6.530099
# 60   5.583789   4.582241   5.925459  -3.122819  -5.088951  -4.637854
# 61   4.765360   5.572549   5.973089  -6.079828  -6.033159  -3.934726
# 62   5.039861   6.577805   4.457692  -5.175924  -4.680317  -4.661884
# 63   4.697769   4.600304   4.316783  -4.646899  -4.840725  -4.927589
# 64   5.407654   6.149660   4.237420  -5.021579  -5.805116  -3.496296
# 65   4.105859   7.357035   3.824973  -4.228207  -5.384843  -5.973314
# 66   5.237117   6.746960   4.603443  -5.152829  -6.854860  -5.279041
# 67   4.949865   5.415263   4.058810  -3.624746  -5.810661  -3.138589
# 68   5.252836   6.820049   4.782567  -6.351235  -5.978817  -6.011008
# 69   5.616190   5.799121   5.124407  -3.620107  -5.512795  -4.851195
# 70   5.067872   4.984517   6.182709  -5.336383  -4.516707  -5.703969
# 71   4.226973   4.822580   5.692611  -5.389765  -5.044311  -5.452246
# 72   6.071524   3.481512   8.029383  -6.055112  -6.055259  -6.255305
# 73   7.391641   5.059103   3.787793  -3.041820  -3.802031  -5.810256
# 74   5.277824   4.272563   4.870127  -6.598770  -3.143120  -5.025673
# 75   4.186388   3.837097   5.414781  -3.737113  -4.523212  -5.958027
# 76   6.354408   4.824496   5.006216  -5.072979  -4.839745  -5.381270
# 77   5.153918   3.603332   6.880928  -4.620856  -4.184614  -7.263228
# 78   6.112424   5.333547   4.868795  -6.072101  -2.834850  -5.840046
# 79   5.389222   4.569140   5.981655  -4.511325  -4.385044  -4.899481
# 80   6.254856   3.422902   4.909223  -5.531162  -4.940593  -5.836310
# 81   3.511435   6.021757   4.398380  -4.530171  -5.557578  -4.557679
# 82   6.243028   4.416283   3.851591  -4.820164  -4.287399  -4.791096
# 83   3.972883   4.017579   5.616942  -2.668421  -6.213763  -4.816004
# 84   5.646885   3.793863   5.246928  -5.084320  -4.332774  -4.966168
# 85   5.303484   4.654340   5.199125  -5.239130  -3.713061  -4.473316
# 86   3.140579   4.054933   5.567626  -4.626052  -4.703358  -5.028605
# 87   5.090650   4.136561   4.604413  -4.015521  -4.311011  -5.446234
# 88   4.876373   5.944892   3.723252  -4.511636  -5.980926  -5.383505
# 89   6.153768   4.972901   3.088429  -4.570742  -4.649980  -4.879863
# 90   3.704383   6.052040   3.653583  -4.324947  -5.448458  -3.983996
# 91   4.148793   5.590005   4.646451  -5.875992  -4.575903  -4.777507
# 92   4.521143   6.273618   5.393506  -4.888772  -2.225518  -3.293018
# 93   5.888781   3.481825   5.398327  -3.368177  -4.665367  -5.400561
# 94   4.788273   2.034275   5.368705  -5.255446  -6.075079  -5.295260
# 95   5.728894   4.660829   5.072960  -5.960578  -4.951044  -3.975907
# 96   4.954718   4.733051   5.411436  -5.809033  -6.193312  -5.479789
# 97   3.104683   4.895616   6.238464  -5.866025  -5.486002  -4.344293
# 98   5.951366   5.769844   6.295771  -5.354228  -4.778081  -6.423437
# 99   5.972146   6.951955   5.630261  -4.953334  -5.277490  -4.634101

# %% [markdown]
# ### Merging Dataframes
#
# Similar to SQL joins, we'll combine two DataFrames using a unique ID found in both DataFrames.

# %%
#Create sample dataframes
A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %% [markdown]
# Inner join: Only include observations found in both A and B:

# %%
#Use pd.merge to do join. Set how = "inner"
pd.merge(A, B, how = "inner")
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %%
#Setting on = "color" does same thing
pd.merge(A, B, how='inner', on="color")
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %% [markdown]
# If you don't set column to do the join on, then pandas will use the shared column. In this example, the shared column is "color".

# %% [markdown]
# Outer join: Include observations found in either A or B:

# %%
#Set how = "outer"
pd.merge(A, B, how= "outer")
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %% [markdown]
# Left join: Include all observations found in A:

# %%
#Set how = "left"
pd.merge(A, B, how = "left")
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %% [markdown]
# Right join: Include all observations found in B:

# %%
pd.merge(A, B, how = "right")
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L

# %% [markdown]
# Another example

# %%
#Make dataframes from dictionaries
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}


data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
#Concatenate data1 and data2 on axis 0 assign it to all_data
all_data = pd.concat([data1, data2])

# %%
#Inner join all_data and data on the subject_id column
# pd.merge(all_data, data1, on="subject_id")

# %% [markdown]
# ### Exercise time
#
# 1. Merge only the data that has the same 'subject_id' on both data1 and data2
#
# 2. Merge all values in data1 and data2, with matching records from both sides where available.

# %%
#Answer 1 
pd.merge(data1, data2, on = "subject_id", how="inner")
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
#Answer 2
pd.merge(data1, data2, on = "subject_id", how="outer")
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# ### More resources concatenating, merging, and other ways to transforms data in pandas.
#
# http://www.datacarpentry.org/python-ecology-lesson/04-merging-data/
# https://github.com/shanealynn/Pandas-Merge-Tutorial/blob/master/Pandas%20Merge%20Tutorial.ipynb
# https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/
# https://pythonprogramming.net/concatenate-append-data-analysis-python-pandas-tutorial/
# https://www.dezyre.com/data-science-in-python-tutorial/pandas-introductory-tutorial-part-3
#
# Pivot tables: http://pbpython.com/pandas-pivot-table-explained.html

# %% [markdown]
# This brings us to the end of the pandas section. We'll learn some pandas things but this is the last time pandas is the last lesson. There's a lot more to learn so I encourage to take advantage of the resources I gave you.

# %% [markdown]
# ## Plotting

# %%
#import plotting library
import matplotlib.pyplot as plt
#Don't forget this part!
# %matplotlib inline

# %%
#Make some random numpy arays

a = np.random.rand(100)
b = np.random.rand(100)*3 + 2

# %% [markdown]
# Line plots

# %%
#Use .plot() to make a line plot with a
plt.plot(a)
plt.show()

# %%
#Change color to green
# ?plt.plot(a, c="g")
plt.show()

# %%
#Change thickness of the line
plt.plot(a, c="c", linewidth = .3);

# %%
#Change opaqueness of plot. Scale is 0.0-1.0. Keyword is alpha
#1.0 is opaque
#0.0 is transparent
plt.plot(a, c="k", alpha = .1);

# %% [markdown]
# 1. Adjust size of plot
# 2. Add some context to the plot

# %%
#Set plot size to 8x6 
plt.figure(figsize=(8,6))

#Call plot with linewidth to 3
plt.plot(a, linewidth = 3)

#Label the x-axis
plt.xlabel("This is the x axis")

#Label the y-axis
plt.ylabel("This is the y axis")


#Give the plot a title
plt.title("Our Fantastic Plot")

# %% [markdown]
# We can combine charts together on a single plot

# %%
#Make line plots of a and b and give them separate colors
plt.plot(a, c="c")
plt.plot(b, c = "y")

# %% [markdown]
# We can display this using subplots

# %%
#Setting size
plt.figure(figsize=(12,4))

#Subplot #1
plt.subplot(1, 2, 1)
plt.plot(a, color='purple')
plt.ylabel('Values')
plt.title('Random Plot 1')

#Subplot #2
plt.subplot(1, 2, 2)
plt.plot(b, color='green')
plt.ylabel('Values')
plt.title('Random Plot 2')

#tight_layout() adds spacing between plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter plots

# %%
#Plot a vs b using a scatter plot
#Adjust size
plt.figure(figsize=(8,6))

#Call .scatter() method. Set s= 30 to increase size of plot.
plt.scatter(a, b, s = 30)

#Label x and y axes
plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %%
#Lets call same plot but let's impose some limits on it

plt.figure(figsize=(8, 5))

#Call .scatter() method. Set s= 30 to increase size of plot.
plt.scatter(a, b, s=30)

#Label x and y axes
plt.xlabel("A array")
plt.ylabel("B array")

#Limits on both axes
plt.xlim(0.4, 0.8)
plt.ylim(3, 4)
plt.show()

# %% [markdown]
# Change the size and color of individual dots

# %%
#Create numpy array of sizes
sizes = np.random.random(100)*200

#Create numpy array of colors randomly selected from color_list a 100 times
color_list = ["r", "g", "y", "b"]
colors = np.random.choice(color_list, size=100)

# %%
sizes[:20]
# Out:
# array([  14.72915901,  116.67502502,  143.07083044,  122.50953373,
#         166.88815298,  191.68148601,  177.41085842,  174.7888629 ,
#          89.19203256,  167.11841587,   75.63355038,  121.63535218,
#          51.56729612,  158.61830437,  120.37425413,    1.68009262,
#         117.92918237,   66.03287631,  133.28556072,  198.33484457])

# %%
colors[:20]
# Out:
# array(['b', 'b', 'y', 'b', 'b', 'g', 'r', 'g', 'b', 'r', 'r', 'y', 'r',
#        'y', 'b', 'r', 'r', 'b', 'b', 'r'],
#       dtype='|S1')

# %% [markdown]
# Pass sizes and colors in to scatter plot function

# %%
#Set size to 8x5
plt.figure(figsize=(8,5))

#Set s to sizes and c to colors
plt.scatter(a, b, s=sizes, c=colors)

plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %% [markdown]
# Voila! We have a colorful scatter plot of with dots of varying sizes
#
# However let's try making it look a little nicer.

# %%
#Load in the fivethirtyeight plot style
plt.style.use("fivethirtyeight")

# %%
#Let's run our scatter plot again
plt.figure(figsize=(8, 5))
plt.scatter(a, b, s=sizes, c=colors)
plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %% [markdown]
# Much better isn't it?

# %%
#Available styles at out disposable

# %%
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %% [markdown]
# Bar plots

# %%
#Lists of seasons and average high temperature for San Francisco
seasons = ["Spring", "Summer", "Fall", "Winter"]
sf_temps = [64, 68, 63, 59]

# %%
#Plot bar plot of temperatures on y axis and season on x axis

#Requires a list of integers to be used as position coordinates.
#Set pos equal to array-range of the length of seasons
pos = np.arange(len(seasons))

#Set bar width to 0.4
w = 0.4

# %%
#Let's fill in the blank together
plt.bar(left = pos, width = w, height= sf_temps , tick_label = seasons, align = "center")
plt.show()

# %% [markdown]
# Same chart but with horizontal orientation. But be careful!

# %%
#Bottom = pos
#Width = sf_temps
#Height = w
#tick_labels = seasons
#align = "center"

plt.barh(bottom = pos, width = sf_temps, height = w, tick_label = seasons, align="center")
plt.show()

# %% [markdown]
# Compare San Francisco to Los Angeles and New York

# %%
#List of temperatures for LA and NY
la_temps = [73, 87, 74, 62]
ny_temps = [58, 85, 53, 39]

# %%
#Plot all three cities together on same plot

w = 0.2
#Bar plot number 1: San Francisco

#Shift positioning to the left by width value
plt.bar(pos-w, width=w, height=sf_temps, align="center")

#Bar plot number 2: Los Angeles
#Keep pos the same
#The middle chart gets the tick_label
#We only need to call it once because they all have the same labels
plt.bar(pos, width=w, height=la_temps, color="r", tick_label=seasons, align = "center")

#Bar plot number 3: New York
#Shift positioning to the right by width value
plt.bar(pos + w, width=w, height=ny_temps, color = "g", align = "center")

plt.ylabel("Average Temperatures")
#Set a legend. bbox_to_anchor moves legend out of the way
plt.legend(["San Francisco", "Los Angeles", "New York"],
          fontsize="small",
          bbox_to_anchor=(1.4, .95))
plt.show()

# %% [markdown]
# ### Statistical plots

# %% [markdown]
# Histograms

# %%
#Create numpy array with a normal distribution of 3000 values, mean 10, and std of 3
a = np.random.normal(loc=10,size=3000, scale=3)

# %%
#Make a histogram of a

plt.hist(a);

# %% [markdown]
# Shows data actually is a normal distribution

# %% [markdown]
# Let's make some changes

# %%
#Set bins = 20 and normed=True

plt.hist(a, bins=40, normed=True);

# %% [markdown]
# What is the difference?

# %% [markdown]
# Lets show two histograms on the same plot

# %%
#Create another numpy array but this time with a gamma distribution

b = np.random.normal(loc=5,size=3000, scale=1)
#Call hist on a and b. Uses bins =50 for both.
#Use different colors for both plots
plt.figure(figsize=(9, 8))
plt.hist(a, bins=50, color="r", alpha = .5)
plt.hist(b, bins= 50, alpha =.5);
# plt.shot()

# %% [markdown]
# Compare and contrast the two plots

# %% [markdown]
# #### Boxplots

# %%
#Set random seed so we all generate the same random data data
np.random.seed(42)

# %% [markdown]
# Who knows what random seed does ?

# %%
np.random.seed(42)
x = np.random.normal(10, 5, 1000)
# Generate box plot.

# %%
x[:10]
# Out:
# array([ 12.48357077,   9.30867849,  13.23844269,  17.61514928,
#          8.82923313,   8.82931522,  17.89606408,  13.83717365,
#          7.65262807,  12.71280022])

# %%
plt.boxplot(x);

# %% [markdown]
# - The box in the boxplot represents the middle 50% of values, all the values between the 25th and 75th percentile. Aka the interquartile range "IQR". The red line represents the median.
#
# - The whiskers will extend up and down up to a distance of 1.5x the IQR away from the top and bottom of the box. If all values are within that range, the whiskers will go to the max and min of the variable.

# %% [markdown]
# <b> Which do you think is better for showing the distribution of a set of numbers? Boxplot or histogram? Why?<b>

# %% [markdown]
# ### Plotting with Pandas
# <br>
# We can create charts directly from pandas dataframes and series. Let's find out how to do so with pokemon data!
#
# Data source:https://www.kaggle.com/abcsds/pokemon

# %%
#Data path
path  = "../data/Pokemon.csv"

#Load pokemon data into a pandas dataframe
pm = pd.read_csv(path)

# %%
pm.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation Legendary
# 0       65       65     45           1     False
# 1       80       80     60           1     False
# 2      100      100     80           1     False
# 3      122      120     80           1     False
# 4       60       50     65           1     False

# %%
#Clean up the columns by lowercasing them and getting rid spaces and periods
pm.columns = pm.columns.str.lower().str.replace(" ", "_").str.replace(".", "")
pm.head()
# Out:
#    #                   name type_1  type_2  total  hp  attack  defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    sp_atk  sp_def  speed  generation legendary
# 0      65      65     45           1     False
# 1      80      80     60           1     False
# 2     100     100     80           1     False
# 3     122     120     80           1     False
# 4      60      50     65           1     False

# %%
#Drop the hashtag column from data
pm.drop("#", axis=1, inplace=True)

# %% [markdown]
# Use can matplotlib on pandas data

# %%
plt.hist(pm.total)
plt.show()

# %% [markdown]
# But we're going to use the built-in plotting functionality of pandas.

# %%
#Same graph as above but using pandas

pm.total.plot(kind="hist");

# %% [markdown]
# Make a histogram of all the numerical columns in the data

# %%
#Call .hist() on pm and drop 
pm.hist(figsize=(12,9))
plt.tight_layout()
plt.show()

# %% [markdown]
# Pandas bar plots

# %%
#Assign pm.type_1 to poke_type
poke_type = pm.type_1

# %% [markdown]
# Use a bar plot to visualize the counts of the various types of pokemon.

# %%
#Use value_counts to get the tallies of the types and assign to type_vc

type_vc = poke_type.value_counts()

#Call .plot on type_vc and set kind = "bar"

type_vc.plot(kind="bar", rot= 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's try this again but with some adjustments

# %%
#Set kind = "barh" to make it a horizontal plot
#Set figsize= (8, 5) to adjust size
#Set color = "g"
#Set alpha = 0.6
#Set width = 1
type_vc.plot(kind="barh", figsize=(8,5), color="g", width = 1);

# %% [markdown]
# Pandas scatter plots

# %%
#View data
pm.head()
# Out:
#                     name type_1  type_2  total  hp  attack  defense  sp_atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49      65
# 1                Ivysaur  Grass  Poison    405  60      62       63      80
# 2               Venusaur  Grass  Poison    525  80      82       83     100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     122
# 4             Charmander   Fire     NaN    309  39      52       43      60
#
#    sp_def  speed  generation legendary
# 0      65     45           1     False
# 1      80     60           1     False
# 2     100     80           1     False
# 3     120     80           1     False
# 4      50     65           1     False

# %% [markdown]
# Let's visualize attack vs defense

# %%
#Specify column names for the x and y axes
#Set kind = "scatter"
pm.plot(kind="scatter", x ="defense", y= "attack");

# %% [markdown]
# What is the relationship between the two attributes?

# %% [markdown]
# Let's colorify the plot!

# %%
#Same code as before but this time specify legendary as the color
pm.plot(x = "defense", y = "attack", kind = "scatter" , c = pm.legendary , figsize=( 8, 6))
plt.show()

# %% [markdown]
# What is the difference between legendary and non-legendary pokemon when it comes to attack and defense?

# %% [markdown]
# Specify our own color scheme

# %%
#Create color dictionary, which we'll use to map over the pandas series. 
#Convert False to yellow and True to green
color_dict = {False:"y", True:"g"}

#Create new pandas series object which is the legendary column but with color-encoding
colors = pm.legendary.map(color_dict)

# %%
#Scatter with new color encoding
pm.plot(x ="defense" , y = "attack", kind = "scatter" , c = colors, figsize=(10, 7))
plt.show()

# %% [markdown]
# Let's try a similar plot but this time we'll use point size to visualize the speed of the pokemon

# %%
#Set s = pm.speed
pm.plot(x="defense", y = "attack", kind="scatter",alpha=.4, s = pm.speed, figsize=(10, 7))
plt.show()

# %% [markdown]
# Combine both of the previous two plots into one

# %%
pm.plot(x = "defense", y = "attack", kind = "scatter", c=colors, s = pm.speed, alpha=.4)
plt.show()

# %% [markdown]
# ### Grouped plot: boxes and bars

# %% [markdown]
# Grouped box plots

# %%
#Use pandas to make box plot of the total column
pm.total.plot(kind="box")
plt.show()

# %%
#Box plot of attack points grouped by type_1
#Column is set equal to the continuous variable we wish to display
#By is set equal to the categorical variable that determines the various individual boxplots
plt.figure(figsize=(8, 8))
pm.boxplot(column = "total", by = "generation" )
plt.tight_layout()
plt.show()

# %% [markdown]
# Grouped bar plots

# %%
#List of columns to use for this exercise
cols = ["hp", "attack", "defense"]

# %%
#Group by generation
#Pass in cols
#Call .mean()
#Call .plot() with bar plot and size of 10x8
#Set title to "Grouped Bar Plots"
pm.groupby("generation")[cols].mean().plot(kind="bar", figsize= (10, 8),
                                          title = "Grouped Bar Plots")
plt.show()

# %% [markdown]
# Stack 'em

# %%
#Same code as above but set stacked = True
pm.groupby("generation")[cols].mean().plot(kind="bar", figsize= (10, 8), stacked = True,
                                          title = "Grouped Bar Plots")
#Move legend box to center right
plt.legend(loc="right")
plt.show()

# %% [markdown]
# Which type of bar plot do you prefer? The stacked or the side by side? Why?

# %% [markdown]
# ## More resources on plotting in Python
#
# https://github.com/matplotlib/AnatomyOfMatplotlib/blob/master/AnatomyOfMatplotlib-Part1-Figures_Subplots_and_layouts.ipynb
#
# https://github.com/rasbt/matplotlib-gallery/tree/master/ipynb
#
# https://github.com/jbwhit/jupyter-tips-and-tricks/tree/master/notebooks
# <br><br>
# From [PythonDataScienceHandbook](https://github.com/jakevdp/PythonDataScienceHandbook):
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.01-Simple-Line-Plots.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.02-Simple-Scatter-Plots.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.05-Histograms-and-Binnings.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.04-Density-and-Contour-Plots.ipynb
#
#
#
# Check out the matplotlib cheat sheet in the extracurricular directory.

# %% [markdown]
# ## Class exercise
#
# Pick out a dataset from the data directory and explore it as much as possible using the visualizations we just learned. I want this to be a freeform exercise where you go out in the wild and explore on your own.
#
# You can choose any dataset you like but I recommend:
# - auto-mpg
# - red_wine_quality
# - simple_demographics
# - movie_metadata
# - drinks
#
# Everytime you make visualization, I want you to guess what you are going to see. Make an expectation and then see if you're proven wrong or right.
#
# Explore:
#     - The distributions of certain features (Histograms and bar plots)
#     - Use bar plots to count categorical data
#     - Relationships between different features. Do those relationships change when apply certain conditions

# %%
#Have fun!
