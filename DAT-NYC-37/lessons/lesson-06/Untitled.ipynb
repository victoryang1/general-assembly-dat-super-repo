# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# X = np.random.normal(size=100000)

# %% [markdown]
# series = pd.Series(X)

# %%
series.hist(bins = 100);

# %%
sampled = series[(series < series.mean() - series.std()) | (series > series.mean() + series.std())]

# %%
sampled.hist(bins=100)
